# %% [markdown]
# # Extract Weather Information from Weather Map
#
# ---
#
#
# By Mauricio Hernandez

# %% [markdown]
# Goal(s):
# - Collect and download data from a set of locations using the WeatherMap API.

# %% [markdown]
# ---
# See documentation at: See documentation at: https://openweathermap.org/api/one-call-3

# %%
#Import libraries
import requests
import pandas as pd
import os
import json
#import datetime
import time
from datetime import timezone
from datetime import datetime
from google.colab import drive
from datetime import timedelta

# %%
#Connect to google drive
drive.mount('/content/gdrive')
#access path where notebook is stored
#path = "/content/gdrive/MyDrive/Women In Technology/Niharika Yalla/Code"
path = "/content/gdrive/MyDrive/Lumiere Program/Niharika Yalla/Code"
#Change the working directory to the folder
os.chdir(path)
# Out:
# Mounted at /content/gdrive

# %%
#Check files
os.listdir(path)
# Out:
# ['Extract Weather Info WeatherMap.ipynb',
#  'Hello.ipynb',
#  'weather_info.csv',
#  'Read_csv_Nikki.ipynb',
#  'car_prices',
#  'Predict_car_prices.ipynb',
#  'Predict_car_prices_Nikki',
#  'Read_CA_Weather_forecast.ipynb',
#  'weather_San Francisco_11-04-2023_13-03.csv',
#  'weather_San Diego_11-04-2023_13-04.csv',
#  'CA_Forecast_nikki ',
#  'Read_csv_Mau.ipynb',
#  'weather_files_ combine_nikki.ipynb',
#  'Combine_actuals_weather_files.ipynb',
#  'Combine_forecast_weather.ipynb',
#  'Combine weather forecasts and actuals.ipynb',
#  'Current_Forecast_WeatherMap.ipynb']

# %%
#Read API_key
# In a text file write NREL api key in the first line and save it
with open('../Data/Inputs/WeatherMap_APIKey') as f:
    line = f.readline()
api_key = line.replace('\n', '')

# %% [markdown]
# *Define longitude and latitude and other parameters*

# %% [markdown]
# ## Download Historical Free Data

# %%
sites = { 1: {'Name': 'San Francisco', 'Latitude': 37.7749, 'Longitude': -122.4194, 'Timezone': 'America/Los Angeles', 'Elevation': 52.0},
          2: {'Name': 'San Diego', 'Latitude': 32.7157, 'Longitude': -117.1611, 'Timezone': 'America/Los Angeles', 'Elevation': 19.0},
          3: {'Name': 'Los Angeles', 'Latitude': 34.0549, 'Longitude': -118.2426, 'Timezone': 'America/Los Angeles', 'Elevation': 89.0},
          4: {'Name': 'Sacramento', 'Latitude': 38.5816, 'Longitude': -121.4944, 'Timezone': 'America/Los Angeles', 'Elevation': 8.0}
         }

# %%
#Example of API call
#https://history.openweathermap.org/data/2.5/history/city?lat=35.05&lon=-106.53&type=hour&start=1672444800&end=1672527600&appid=<YOUR API KEY>
#https://history.openweathermap.org/data/2.5/history/city?lat=35.05&lon=-106.53&type=hour&start=1672444800&end=1672527600&appid=499817a2d0296f45499bb26bf6039e01
#https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=39.099724&lon=-94.578331&dt=1643803200&appid={API key}
#current weather
#https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# %%
def req_current_data(api_key, lon, lat):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/data/2.5/weather?'
  params = {
      'appid': api_key,
      'lat': lat,
      'lon': lon,
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
#define coordinates and timeframe (all values in UTC Zone)
site_number = 1
latitude = sites[site_number]['Latitude']
longitude = sites[site_number]['Longitude']
#start_timestamp = start_utc.replace(tzinfo=timezone.utc).timestamp()
#end_timestamp = end_utc.replace(tzinfo=timezone.utc).timestamp()
sites[site_number]
# Out:
# {'Name': 'San Francisco',
#  'Latitude': 37.7749,
#  'Longitude': -122.4194,
#  'Timezone': 'America/Los Angeles',
#  'Elevation': 52.0}

# %%
#info is read for each week because of the limitations of the API call
df_weather = pd.DataFrame()
df_week = pd.DataFrame()

resp = req_current_data(api_key= api_key, lon=longitude, lat=latitude)

json_data = json.loads(resp.text)

df_weather = pd.json_normalize(json_data['main'])
df_wind = pd.json_normalize(json_data['wind'])

df_weather.insert(0, "date_machine", json_data['dt'])
df_weather.insert(0, "dt_utc", df_weather.date_machine.apply(datetime.fromtimestamp))
df_weather['clouds'] = pd.json_normalize(json_data['clouds'])
df_weather['visibility'] = json_data['visibility']
df_weather
# Out:
# {"coord":{"lon":-117.1628,"lat":32.7174},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"base":"stations","main":{"temp":298.61,"feels_like":298.33,"temp_min":292.46,"temp_max":305.74,"pressure":1015,"humidity":43},"visibility":10000,"wind":{"speed":5.14,"deg":320},"clouds":{"all":40},"dt":1699137698,"sys":{"type":1,"id":5771,"country":"US","sunrise":1699106924,"sunset":1699145739},"timezone":-25200,"id":5391811,"name":"San Diego","cod":200}
#                dt_utc  date_machine    temp  feels_like  temp_min  temp_max  \
# 0 2023-11-04 22:41:38    1699137698  298.61      298.33    292.46    305.74
#
#    pressure  humidity  clouds  visibility
# 0      1015        43      40       10000

# %%
#Save results
df_weather.to_csv('../Data/Inputs/weather_{}_{}.csv'.format(sites[site_number]['Name'], datetime.now().strftime("%m-%d-%Y_%H-%M")), index = False)

# %% [markdown]
# ## Download Historical Data

# %%
#Example of API call
#https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=39.099724&lon=-94.578331&dt=1643803200&appid={API key}
#499817a2d0296f45499bb26bf6039e01

# %%
def convert_timestamp_to_text(datestamp, date_format):
  date_str = datetime.utcfromtimestamp(datestamp).strftime(date_format)
  return date_str

# %%
def req_hist_data_v3(api_key, lon, lat, date):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/data/3.0/onecall/timemachine?'
  params = {
      'appid': api_key,
      'lat': lat,
      'lon': lon,
      'dt': date,
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
def req_historical_day_weather(date_str, api_key: str, lon:float, lat:float):
  df_weather = pd.DataFrame()
  df_weather_hr = pd.DataFrame()

  date_format = '%Y-%m-%d %H:%M:%S'
  date = datetime.strptime(date_str, date_format)

  #for h in range(1, 24*154 + 1):
  for h in range(1, 24*1+1): # one day
    date_timestamp = date.replace(tzinfo=timezone.utc).timestamp()
    resp = req_hist_data_v3(api_key= api_key, lon=longitude, lat=latitude, date=int(date_timestamp))
    json_data = json.loads(resp.text)

    df_weather_hr = pd.json_normalize(json_data['data'])
    df_weather_hr['dt'] = df_weather_hr.apply(lambda x: convert_timestamp_to_text(x['dt'], date_format), axis =1)
    df_weather_hr['sunrise'] = df_weather_hr.apply(lambda x: convert_timestamp_to_text(x['sunrise'], date_format), axis =1)
    df_weather_hr['sunset'] = df_weather_hr.apply(lambda x: convert_timestamp_to_text(x['sunset'], date_format), axis =1)
    df_weather_hr.insert(1, 'timezone', json_data['timezone'])
    df_weather_hr.insert(2, 'timezone_offset', json_data['timezone_offset'])

    df_weather = pd.concat([df_weather, df_weather_hr], ignore_index=True)
    date = date  + timedelta(hours = 1)
  return df_weather

for day in range(1, 21):
  date_str = '2023-11-{} 00:00:00'.format(day)
  site_number = 4
  latitude = sites[site_number]['Latitude']
  longitude = sites[site_number]['Longitude']

  print('Requesting data from site: {} for day {}'.format(sites[site_number]['Name'], date_str))
  df_day_weather = req_historical_day_weather(date_str, api_key= api_key, lon = longitude, lat = latitude)

  # Save file in Data/Outputs folder
  file_namepath = '../Data/Inputs/weather_{}_{}.csv'.format(sites[site_number]['Name'], date_str.split()[0])
  print("Saving weather info in file {}".format(file_namepath))
  df_day_weather.to_csv(file_namepath, index = False)

df_day_weather.head()
# Out:
# Requesting data from site: Sacramento for day 2023-11-1 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698796800,"sunrise":1698762680,"sunset":1698800862,"temp":295.1,"feels_like":294.08,"pressure":1021,"humidity":28,"dew_point":275.78,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698800400,"sunrise":1698762680,"sunset":1698800862,"temp":292.81,"feels_like":291.72,"pressure":1021,"humidity":34,"dew_point":276.53,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":20,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698804000,"sunrise":1698762680,"sunset":1698800862,"temp":289.35,"feels_like":288.33,"pressure":1021,"humidity":50,"dew_point":278.93,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":290,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698807600,"sunrise":1698762680,"sunset":1698800862,"temp":286.97,"feels_like":285.92,"pressure":1021,"humidity":58,"dew_point":278.86,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698811200,"sunrise":1698762680,"sunset":1698800862,"temp":285.34,"feels_like":284.31,"pressure":1022,"humidity":65,"dew_point":278.96,"clouds":20,"visibility":10000,"wind_speed":1.54,"wind_deg":20,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698814800,"sunrise":1698762680,"sunset":1698800862,"temp":284.58,"feels_like":283.55,"pressure":1021,"humidity":68,"dew_point":278.89,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698818400,"sunrise":1698762680,"sunset":1698800862,"temp":283.11,"feels_like":282.71,"pressure":1022,"humidity":72,"dew_point":278.3,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698822000,"sunrise":1698849145,"sunset":1698887194,"temp":282.68,"feels_like":282.68,"pressure":1022,"humidity":73,"dew_point":278.09,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698825600,"sunrise":1698849145,"sunset":1698887194,"temp":280.57,"feels_like":279.81,"pressure":1020,"humidity":79,"dew_point":277.17,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":110,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698829200,"sunrise":1698849145,"sunset":1698887194,"temp":280.34,"feels_like":279.55,"pressure":1020,"humidity":81,"dew_point":277.3,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698832800,"sunrise":1698849145,"sunset":1698887194,"temp":279.38,"feels_like":278.45,"pressure":1020,"humidity":84,"dew_point":276.88,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698836400,"sunrise":1698849145,"sunset":1698887194,"temp":279.34,"feels_like":278.4,"pressure":1020,"humidity":84,"dew_point":276.84,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":20,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698840000,"sunrise":1698849145,"sunset":1698887194,"temp":278.34,"feels_like":276.68,"pressure":1020,"humidity":87,"dew_point":276.36,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698843600,"sunrise":1698849145,"sunset":1698887194,"temp":278.38,"feels_like":276.73,"pressure":1020,"humidity":86,"dew_point":276.23,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":270,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698847200,"sunrise":1698849145,"sunset":1698887194,"temp":278.38,"feels_like":277.31,"pressure":1020,"humidity":86,"dew_point":276.23,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698850800,"sunrise":1698849145,"sunset":1698887194,"temp":280.09,"feels_like":278.72,"pressure":1023,"humidity":87,"dew_point":278.08,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698854400,"sunrise":1698849145,"sunset":1698887194,"temp":282.15,"feels_like":282.15,"pressure":1020,"humidity":78,"dew_point":278.52,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698858000,"sunrise":1698849145,"sunset":1698887194,"temp":286.73,"feels_like":285.66,"pressure":1021,"humidity":58,"dew_point":278.63,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698861600,"sunrise":1698849145,"sunset":1698887194,"temp":289.01,"feels_like":287.98,"pressure":1024,"humidity":51,"dew_point":278.9,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698865200,"sunrise":1698849145,"sunset":1698887194,"temp":291.44,"feels_like":290.45,"pressure":1022,"humidity":43,"dew_point":278.66,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":300,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698868800,"sunrise":1698849145,"sunset":1698887194,"temp":293.76,"feels_like":292.79,"pressure":1022,"humidity":35,"dew_point":277.78,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698872400,"sunrise":1698849145,"sunset":1698887194,"temp":294.19,"feels_like":293.21,"pressure":1021,"humidity":33,"dew_point":277.32,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698876000,"sunrise":1698849145,"sunset":1698887194,"temp":295.01,"feels_like":294.09,"pressure":1020,"humidity":32,"dew_point":277.59,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":290,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698879600,"sunrise":1698849145,"sunset":1698887194,"temp":295.93,"feels_like":295.02,"pressure":1020,"humidity":29,"dew_point":276.99,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":10,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-1.csv
# Requesting data from site: Sacramento for day 2023-11-2 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698883200,"sunrise":1698849145,"sunset":1698887194,"temp":296.12,"feels_like":295.23,"pressure":1020,"humidity":29,"dew_point":277.15,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698886800,"sunrise":1698849145,"sunset":1698887194,"temp":293.42,"feels_like":292.52,"pressure":1020,"humidity":39,"dew_point":279.03,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698890400,"sunrise":1698849145,"sunset":1698887194,"temp":290.29,"feels_like":289.39,"pressure":1019,"humidity":51,"dew_point":280.08,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698894000,"sunrise":1698849145,"sunset":1698887194,"temp":287.82,"feels_like":286.91,"pressure":1019,"humidity":60,"dew_point":280.15,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698897600,"sunrise":1698849145,"sunset":1698887194,"temp":286.51,"feels_like":285.62,"pressure":1020,"humidity":66,"dew_point":280.3,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":40,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698901200,"sunrise":1698849145,"sunset":1698887194,"temp":284.61,"feels_like":283.56,"pressure":1018,"humidity":67,"dew_point":278.7,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698904800,"sunrise":1698849145,"sunset":1698887194,"temp":284.15,"feels_like":283.16,"pressure":1018,"humidity":71,"dew_point":279.1,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":260,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698908400,"sunrise":1698935611,"sunset":1698973528,"temp":283.07,"feels_like":283.07,"pressure":1019,"humidity":78,"dew_point":279.42,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698912000,"sunrise":1698935611,"sunset":1698973528,"temp":282.88,"feels_like":281.98,"pressure":1019,"humidity":75,"dew_point":278.67,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":140,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698915600,"sunrise":1698935611,"sunset":1698973528,"temp":282.76,"feels_like":282.31,"pressure":1019,"humidity":77,"dew_point":278.93,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698919200,"sunrise":1698935611,"sunset":1698973528,"temp":281.61,"feels_like":281,"pressure":1019,"humidity":84,"dew_point":279.07,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":300,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698922800,"sunrise":1698935611,"sunset":1698973528,"temp":281.38,"feels_like":280.23,"pressure":1019,"humidity":83,"dew_point":278.67,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698926400,"sunrise":1698935611,"sunset":1698973528,"temp":281.34,"feels_like":280.69,"pressure":1019,"humidity":80,"dew_point":278.1,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698930000,"sunrise":1698935611,"sunset":1698973528,"temp":280.57,"feels_like":279.81,"pressure":1019,"humidity":84,"dew_point":278.05,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698933600,"sunrise":1698935611,"sunset":1698973528,"temp":280.34,"feels_like":280.34,"pressure":1019,"humidity":84,"dew_point":277.82,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698937200,"sunrise":1698935611,"sunset":1698973528,"temp":280.38,"feels_like":279.59,"pressure":1020,"humidity":86,"dew_point":278.2,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":40,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698940800,"sunrise":1698935611,"sunset":1698973528,"temp":285.15,"feels_like":284.29,"pressure":1021,"humidity":72,"dew_point":280.27,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698944400,"sunrise":1698935611,"sunset":1698973528,"temp":288.97,"feels_like":288.02,"pressure":1024,"humidity":54,"dew_point":279.69,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698948000,"sunrise":1698935611,"sunset":1698973528,"temp":291.64,"feels_like":290.75,"pressure":1023,"humidity":46,"dew_point":279.82,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698951600,"sunrise":1698935611,"sunset":1698973528,"temp":293.56,"feels_like":292.65,"pressure":1023,"humidity":38,"dew_point":278.78,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":180,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698955200,"sunrise":1698935611,"sunset":1698973528,"temp":295.5,"feels_like":294.68,"pressure":1022,"humidity":34,"dew_point":278.89,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":200,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698958800,"sunrise":1698935611,"sunset":1698973528,"temp":295.97,"feels_like":295.2,"pressure":1022,"humidity":34,"dew_point":279.3,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698962400,"sunrise":1698935611,"sunset":1698973528,"temp":296.14,"feels_like":295.36,"pressure":1021,"humidity":33,"dew_point":279.02,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698966000,"sunrise":1698935611,"sunset":1698973528,"temp":297.32,"feels_like":296.58,"pressure":1019,"humidity":30,"dew_point":278.67,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-2.csv
# Requesting data from site: Sacramento for day 2023-11-3 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698969600,"sunrise":1698935611,"sunset":1698973528,"temp":295.91,"feels_like":295.21,"pressure":1022,"humidity":37,"dew_point":280.48,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698973200,"sunrise":1698935611,"sunset":1698973528,"temp":294.22,"feels_like":293.45,"pressure":1022,"humidity":41,"dew_point":280.47,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698976800,"sunrise":1698935611,"sunset":1698973528,"temp":292.92,"feels_like":292.15,"pressure":1022,"humidity":46,"dew_point":280.98,"clouds":0,"visibility":10000,"wind_speed":4.12,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698980400,"sunrise":1698935611,"sunset":1698973528,"temp":291.64,"feels_like":290.88,"pressure":1021,"humidity":51,"dew_point":281.33,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698984000,"sunrise":1698935611,"sunset":1698973528,"temp":290.84,"feels_like":290.05,"pressure":1022,"humidity":53,"dew_point":281.15,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698987600,"sunrise":1698935611,"sunset":1698973528,"temp":290.08,"feels_like":289.21,"pressure":1022,"humidity":53,"dew_point":280.45,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698991200,"sunrise":1698935611,"sunset":1698973528,"temp":289.39,"feels_like":288.56,"pressure":1022,"humidity":57,"dew_point":280.87,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698994800,"sunrise":1699022076,"sunset":1699059863,"temp":288.86,"feels_like":288.05,"pressure":1022,"humidity":60,"dew_point":281.13,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":290,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1698998400,"sunrise":1699022076,"sunset":1699059863,"temp":288.94,"feels_like":288.04,"pressure":1022,"humidity":56,"dew_point":280.19,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699002000,"sunrise":1699022076,"sunset":1699059863,"temp":288.2,"feels_like":287.3,"pressure":1021,"humidity":59,"dew_point":280.26,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":10,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699005600,"sunrise":1699022076,"sunset":1699059863,"temp":287.17,"feels_like":286.25,"pressure":1022,"humidity":62,"dew_point":280.01,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699009200,"sunrise":1699022076,"sunset":1699059863,"temp":286.22,"feels_like":285.38,"pressure":1021,"humidity":69,"dew_point":280.67,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":10,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699012800,"sunrise":1699022076,"sunset":1699059863,"temp":284.93,"feels_like":284.1,"pressure":1021,"humidity":74,"dew_point":280.45,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":270,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699016400,"sunrise":1699022076,"sunset":1699059863,"temp":284.28,"feels_like":283.49,"pressure":1022,"humidity":78,"dew_point":280.59,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":250,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699020000,"sunrise":1699022076,"sunset":1699059863,"temp":284.93,"feels_like":284.17,"pressure":1023,"humidity":77,"dew_point":281.03,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699023600,"sunrise":1699022076,"sunset":1699059863,"temp":283.97,"feels_like":283.2,"pressure":1022,"humidity":80,"dew_point":280.66,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":140,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699027200,"sunrise":1699022076,"sunset":1699059863,"temp":286.38,"feels_like":285.69,"pressure":1023,"humidity":74,"dew_point":281.85,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699030800,"sunrise":1699022076,"sunset":1699059863,"temp":289.69,"feels_like":288.99,"pressure":1022,"humidity":61,"dew_point":282.15,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":180,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699034400,"sunrise":1699022076,"sunset":1699059863,"temp":292.26,"feels_like":291.58,"pressure":1022,"humidity":52,"dew_point":282.18,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":80,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699038000,"sunrise":1699022076,"sunset":1699059863,"temp":293.7,"feels_like":293.04,"pressure":1022,"humidity":47,"dew_point":282.01,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":320,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699041600,"sunrise":1699022076,"sunset":1699059863,"temp":295.58,"feels_like":294.98,"pressure":1021,"humidity":42,"dew_point":282.05,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699045200,"sunrise":1699022076,"sunset":1699059863,"temp":297.22,"feels_like":296.67,"pressure":1020,"humidity":38,"dew_point":282.03,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":360,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699048800,"sunrise":1699022076,"sunset":1699059863,"temp":298.17,"feels_like":297.72,"pressure":1019,"humidity":38,"dew_point":282.88,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":20,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699052400,"sunrise":1699022076,"sunset":1699059863,"temp":298.91,"feels_like":298.53,"pressure":1019,"humidity":38,"dew_point":283.53,"clouds":0,"visibility":10000,"wind_speed":0.45,"wind_deg":195,"wind_gust":1.34,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-3.csv
# Requesting data from site: Sacramento for day 2023-11-4 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699056000,"sunrise":1699022076,"sunset":1699059863,"temp":298.58,"feels_like":298.17,"pressure":1019,"humidity":38,"dew_point":283.24,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":80,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699059600,"sunrise":1699022076,"sunset":1699059863,"temp":296.77,"feels_like":296.34,"pressure":1019,"humidity":44,"dew_point":283.81,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":130,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699063200,"sunrise":1699022076,"sunset":1699059863,"temp":294.03,"feels_like":293.53,"pressure":1020,"humidity":52,"dew_point":283.82,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":150,"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699066800,"sunrise":1699022076,"sunset":1699059863,"temp":292.13,"feels_like":291.62,"pressure":1020,"humidity":59,"dew_point":283.95,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":150,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699070400,"sunrise":1699022076,"sunset":1699059863,"temp":291.1,"feels_like":290.62,"pressure":1020,"humidity":64,"dew_point":284.2,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699074000,"sunrise":1699022076,"sunset":1699059863,"temp":290.17,"feels_like":289.68,"pressure":1020,"humidity":67,"dew_point":284,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":120,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699077600,"sunrise":1699022076,"sunset":1699059863,"temp":290.08,"feels_like":289.47,"pressure":1021,"humidity":63,"dew_point":283,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":200,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699081200,"sunrise":1699108542,"sunset":1699146200,"temp":289.42,"feels_like":288.7,"pressure":1020,"humidity":61,"dew_point":281.9,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":90,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699084800,"sunrise":1699108542,"sunset":1699146200,"temp":288.21,"feels_like":287.47,"pressure":1020,"humidity":65,"dew_point":281.69,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":130,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699088400,"sunrise":1699108542,"sunset":1699146200,"temp":288.14,"feels_like":287.42,"pressure":1020,"humidity":66,"dew_point":281.85,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":120,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699092000,"sunrise":1699108542,"sunset":1699146200,"temp":287.21,"feels_like":286.47,"pressure":1020,"humidity":69,"dew_point":281.62,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":120,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699095600,"sunrise":1699108542,"sunset":1699146200,"temp":287.33,"feels_like":286.58,"pressure":1020,"humidity":68,"dew_point":281.52,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":120,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699099200,"sunrise":1699108542,"sunset":1699146200,"temp":287.08,"feels_like":286.41,"pressure":1020,"humidity":72,"dew_point":282.12,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699102800,"sunrise":1699108542,"sunset":1699146200,"temp":287.1,"feels_like":286.38,"pressure":1020,"humidity":70,"dew_point":281.72,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":140,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699106400,"sunrise":1699108542,"sunset":1699146200,"temp":286.19,"feels_like":285.48,"pressure":1021,"humidity":74,"dew_point":281.67,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":150,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699110000,"sunrise":1699108542,"sunset":1699146200,"temp":284.72,"feels_like":283.92,"pressure":1019,"humidity":76,"dew_point":280.64,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":160,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699113600,"sunrise":1699108542,"sunset":1699146200,"temp":288.23,"feels_like":287.44,"pressure":1019,"humidity":63,"dew_point":281.25,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":170,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699117200,"sunrise":1699108542,"sunset":1699146200,"temp":290.59,"feels_like":289.9,"pressure":1019,"humidity":58,"dew_point":282.25,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":190,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699120800,"sunrise":1699108542,"sunset":1699146200,"temp":293.82,"feels_like":293.14,"pressure":1021,"humidity":46,"dew_point":281.8,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":150,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699124400,"sunrise":1699108542,"sunset":1699146200,"temp":295.96,"feels_like":295.37,"pressure":1021,"humidity":41,"dew_point":282.03,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":170,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699128000,"sunrise":1699108542,"sunset":1699146200,"temp":297.4,"feels_like":296.87,"pressure":1020,"humidity":38,"dew_point":282.19,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":160,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699131600,"sunrise":1699108542,"sunset":1699146200,"temp":297.79,"feels_like":297.41,"pressure":1019,"humidity":42,"dew_point":284.04,"clouds":0,"visibility":10000,"wind_speed":5.14,"wind_deg":150,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699135200,"sunrise":1699108542,"sunset":1699146200,"temp":299.22,"feels_like":299.22,"pressure":1018,"humidity":44,"dew_point":286.03,"clouds":0,"visibility":10000,"wind_speed":5.14,"wind_deg":160,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699138800,"sunrise":1699108542,"sunset":1699146200,"temp":299.88,"feels_like":299.96,"pressure":1018,"humidity":43,"dew_point":286.27,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":180,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-4.csv
# Requesting data from site: Sacramento for day 2023-11-5 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699142400,"sunrise":1699108542,"sunset":1699146200,"temp":299.3,"feels_like":299.3,"pressure":1018,"humidity":44,"dew_point":286.1,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":160,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699146000,"sunrise":1699108542,"sunset":1699146200,"temp":297.57,"feels_like":297.4,"pressure":1018,"humidity":51,"dew_point":286.79,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":170,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699149600,"sunrise":1699108542,"sunset":1699146200,"temp":295.83,"feels_like":295.72,"pressure":1018,"humidity":60,"dew_point":287.67,"clouds":0,"visibility":10000,"wind_speed":5.66,"wind_deg":160,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699153200,"sunrise":1699108542,"sunset":1699146200,"temp":294.09,"feels_like":293.99,"pressure":1018,"humidity":67,"dew_point":287.74,"clouds":0,"visibility":10000,"wind_speed":5.66,"wind_deg":210,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699156800,"sunrise":1699108542,"sunset":1699146200,"temp":292.24,"feels_like":291.82,"pressure":1019,"humidity":62,"dew_point":284.8,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":210,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699160400,"sunrise":1699108542,"sunset":1699146200,"temp":289.75,"feels_like":289.35,"pressure":1019,"humidity":72,"dew_point":284.69,"clouds":20,"visibility":10000,"wind_speed":4.12,"wind_deg":180,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699164000,"sunrise":1699108542,"sunset":1699146200,"temp":289.31,"feels_like":288.94,"pressure":1019,"humidity":75,"dew_point":284.88,"clouds":40,"visibility":10000,"wind_speed":4.63,"wind_deg":180,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699167600,"sunrise":1699195009,"sunset":1699232538,"temp":289.23,"feels_like":288.9,"pressure":1019,"humidity":77,"dew_point":285.2,"clouds":40,"visibility":10000,"wind_speed":5.66,"wind_deg":170,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-25200,"data":[{"dt":1699171200,"sunrise":1699195009,"sunset":1699232538,"temp":288.8,"feels_like":288.48,"pressure":1019,"humidity":79,"dew_point":285.17,"clouds":75,"visibility":10000,"wind_speed":4.63,"wind_deg":170,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699174800,"sunrise":1699195009,"sunset":1699232538,"temp":288.8,"feels_like":288.54,"pressure":1019,"humidity":81,"dew_point":285.55,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":160,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699178400,"sunrise":1699195009,"sunset":1699232538,"temp":288.23,"feels_like":287.93,"pressure":1019,"humidity":82,"dew_point":285.18,"clouds":75,"visibility":10000,"wind_speed":5.66,"wind_deg":160,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699182000,"sunrise":1699195009,"sunset":1699232538,"temp":287.93,"feels_like":287.66,"pressure":1018,"humidity":84,"dew_point":285.26,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":170,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699185600,"sunrise":1699195009,"sunset":1699232538,"temp":288.14,"feels_like":287.86,"pressure":1018,"humidity":83,"dew_point":285.28,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":170,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699189200,"sunrise":1699195009,"sunset":1699232538,"temp":287.57,"feels_like":287.31,"pressure":1019,"humidity":86,"dew_point":285.26,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":170,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699192800,"sunrise":1699195009,"sunset":1699232538,"temp":287.79,"feels_like":287.53,"pressure":1019,"humidity":85,"dew_point":285.3,"clouds":100,"visibility":10000,"wind_speed":3.09,"wind_deg":160,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699196400,"sunrise":1699195009,"sunset":1699232538,"temp":287.57,"feels_like":287.34,"pressure":1019,"humidity":87,"dew_point":285.44,"clouds":75,"visibility":10000,"wind_speed":3.6,"wind_deg":140,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699200000,"sunrise":1699195009,"sunset":1699232538,"temp":288.36,"feels_like":288.16,"pressure":1019,"humidity":85,"dew_point":285.86,"clouds":75,"visibility":10000,"wind_speed":3.09,"wind_deg":150,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"1h":0.25}}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699203600,"sunrise":1699195009,"sunset":1699232538,"temp":289.45,"feels_like":289.28,"pressure":1020,"humidity":82,"dew_point":286.37,"clouds":75,"visibility":10000,"wind_speed":4.63,"wind_deg":160,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699207200,"sunrise":1699195009,"sunset":1699232538,"temp":290.97,"feels_like":290.82,"pressure":1020,"humidity":77,"dew_point":286.89,"clouds":40,"visibility":10000,"wind_speed":4.12,"wind_deg":170,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699210800,"sunrise":1699195009,"sunset":1699232538,"temp":293,"feels_like":292.92,"pressure":1019,"humidity":72,"dew_point":287.81,"clouds":20,"visibility":10000,"wind_speed":4.12,"wind_deg":160,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699214400,"sunrise":1699195009,"sunset":1699232538,"temp":294.22,"feels_like":294.21,"pressure":1018,"humidity":70,"dew_point":288.54,"clouds":20,"visibility":10000,"wind_speed":3.6,"wind_deg":190,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699218000,"sunrise":1699195009,"sunset":1699232538,"temp":294.23,"feels_like":294.25,"pressure":1017,"humidity":71,"dew_point":288.77,"clouds":100,"visibility":10000,"wind_speed":4.63,"wind_deg":190,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699221600,"sunrise":1699195009,"sunset":1699232538,"temp":293.83,"feels_like":293.94,"pressure":1017,"humidity":76,"dew_point":289.45,"clouds":100,"visibility":10000,"wind_speed":4.63,"wind_deg":190,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699225200,"sunrise":1699195009,"sunset":1699232538,"temp":294.18,"feels_like":294.24,"pressure":1016,"humidity":73,"dew_point":289.16,"clouds":40,"visibility":10000,"wind_speed":5.14,"wind_deg":180,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-5.csv
# Requesting data from site: Sacramento for day 2023-11-6 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699228800,"sunrise":1699195009,"sunset":1699232538,"temp":294.22,"feels_like":294.37,"pressure":1016,"humidity":76,"dew_point":289.83,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":360,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699232400,"sunrise":1699195009,"sunset":1699232538,"temp":293.44,"feels_like":293.51,"pressure":1015,"humidity":76,"dew_point":289.07,"clouds":20,"visibility":10000,"wind_speed":4.63,"wind_deg":200,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1699236000,"sunrise":1699195009,"sunset":1699232538,"temp":292.47,"feels_like":292.49,"pressure":1015,"humidity":78,"dew_point":288.54,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":260,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# ...
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700398800,"sunrise":1700405539,"sunset":1700441441,"temp":279.27,"feels_like":278.32,"pressure":1025,"humidity":88,"dew_point":277.43,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":60,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700402400,"sunrise":1700405539,"sunset":1700441441,"temp":280.03,"feels_like":279.19,"pressure":1029,"humidity":87,"dew_point":278.02,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":350,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700406000,"sunrise":1700405539,"sunset":1700441441,"temp":278.96,"feels_like":277.97,"pressure":1030,"humidity":91,"dew_point":277.61,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700409600,"sunrise":1700405539,"sunset":1700441441,"temp":280.57,"feels_like":279.28,"pressure":1030,"humidity":90,"dew_point":279.04,"uvi":0.19,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":360,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700413200,"sunrise":1700405539,"sunset":1700441441,"temp":283.78,"feels_like":282.94,"pressure":1031,"humidity":78,"dew_point":280.11,"uvi":0.68,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":310,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700416800,"sunrise":1700405539,"sunset":1700441441,"temp":285.72,"feels_like":284.81,"pressure":1031,"humidity":68,"dew_point":279.98,"uvi":1.4,"clouds":0,"visibility":10000,"wind_speed":4.12,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700420400,"sunrise":1700405539,"sunset":1700441441,"temp":287.85,"feels_like":286.81,"pressure":1030,"humidity":55,"dew_point":278.91,"uvi":2.09,"clouds":0,"visibility":10000,"wind_speed":7.2,"wind_deg":330,"wind_gust":10.8,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700424000,"sunrise":1700405539,"sunset":1700441441,"temp":288.04,"feels_like":286.89,"pressure":1029,"humidity":50,"dew_point":277.72,"uvi":2.42,"clouds":0,"visibility":10000,"wind_speed":8.75,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700427600,"sunrise":1700405539,"sunset":1700441441,"temp":288.84,"feels_like":287.67,"pressure":1029,"humidity":46,"dew_point":277.27,"uvi":2.21,"clouds":0,"visibility":10000,"wind_speed":8.23,"wind_deg":320,"wind_gust":10.8,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700431200,"sunrise":1700405539,"sunset":1700441441,"temp":288.84,"feels_like":287.67,"pressure":1028,"humidity":46,"dew_point":277.27,"uvi":1.59,"clouds":0,"visibility":10000,"wind_speed":8.23,"wind_deg":350,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700434800,"sunrise":1700405539,"sunset":1700441441,"temp":289.13,"feels_like":287.98,"pressure":1028,"humidity":46,"dew_point":277.53,"uvi":0.83,"clouds":0,"visibility":10000,"wind_speed":7.72,"wind_deg":320,"wind_gust":10.8,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-19.csv
# Requesting data from site: Sacramento for day 2023-11-20 00:00:00
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700438400,"sunrise":1700405539,"sunset":1700441441,"temp":288.57,"feels_like":287.34,"pressure":1028,"humidity":45,"dew_point":276.71,"uvi":0.25,"clouds":0,"visibility":10000,"wind_speed":6.17,"wind_deg":320,"wind_gust":10.8,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700442000,"sunrise":1700405539,"sunset":1700441441,"temp":287.39,"feels_like":286.15,"pressure":1027,"humidity":49,"dew_point":276.84,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":7.72,"wind_deg":330,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700445600,"sunrise":1700405539,"sunset":1700441441,"temp":286.37,"feels_like":285.03,"pressure":1027,"humidity":49,"dew_point":275.9,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":6.69,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700449200,"sunrise":1700405539,"sunset":1700441441,"temp":286,"feels_like":284.72,"pressure":1027,"humidity":53,"dew_point":276.67,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":7.72,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700452800,"sunrise":1700405539,"sunset":1700441441,"temp":285.69,"feels_like":284.44,"pressure":1027,"humidity":55,"dew_point":276.9,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":7.2,"wind_deg":320,"wind_gust":10.8,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700456400,"sunrise":1700405539,"sunset":1700441441,"temp":284.76,"feels_like":283.49,"pressure":1027,"humidity":58,"dew_point":276.79,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":8.75,"wind_deg":350,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700460000,"sunrise":1700405539,"sunset":1700441441,"temp":284.17,"feels_like":282.82,"pressure":1027,"humidity":57,"dew_point":275.99,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":9.26,"wind_deg":330,"wind_gust":11.83,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700463600,"sunrise":1700405539,"sunset":1700441441,"temp":284.16,"feels_like":282.75,"pressure":1026,"humidity":55,"dew_point":275.48,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":9.26,"wind_deg":320,"wind_gust":12.86,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700467200,"sunrise":1700492005,"sunset":1700527805,"temp":283.63,"feels_like":282.17,"pressure":1027,"humidity":55,"dew_point":274.98,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":9.26,"wind_deg":330,"wind_gust":11.83,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700470800,"sunrise":1700492005,"sunset":1700527805,"temp":282.88,"feels_like":279.05,"pressure":1026,"humidity":58,"dew_point":275.02,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":9.77,"wind_deg":330,"wind_gust":13.89,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700474400,"sunrise":1700492005,"sunset":1700527805,"temp":282.45,"feels_like":278.85,"pressure":1026,"humidity":60,"dew_point":275.09,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":8.23,"wind_deg":330,"wind_gust":12.86,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700478000,"sunrise":1700492005,"sunset":1700527805,"temp":282.36,"feels_like":278.48,"pressure":1026,"humidity":60,"dew_point":275.01,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":9.26,"wind_deg":330,"wind_gust":12.35,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700481600,"sunrise":1700492005,"sunset":1700527805,"temp":281.78,"feels_like":277.98,"pressure":1025,"humidity":61,"dew_point":274.69,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":8.23,"wind_deg":340,"wind_gust":11.83,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700485200,"sunrise":1700492005,"sunset":1700527805,"temp":281.37,"feels_like":278.46,"pressure":1026,"humidity":63,"dew_point":274.75,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":5.14,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700488800,"sunrise":1700492005,"sunset":1700527805,"temp":280.56,"feels_like":278.19,"pressure":1025,"humidity":67,"dew_point":274.84,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":360,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700492400,"sunrise":1700492005,"sunset":1700527805,"temp":279.48,"feels_like":278.56,"pressure":1026,"humidity":72,"dew_point":274.81,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700496000,"sunrise":1700492005,"sunset":1700527805,"temp":279.96,"feels_like":277.77,"pressure":1027,"humidity":73,"dew_point":275.47,"uvi":0.2,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":340,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700499600,"sunrise":1700492005,"sunset":1700527805,"temp":283.72,"feels_like":282.27,"pressure":1027,"humidity":55,"dew_point":275.07,"uvi":0.72,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700503200,"sunrise":1700492005,"sunset":1700527805,"temp":284.97,"feels_like":283.49,"pressure":1027,"humidity":49,"dew_point":274.61,"uvi":1.5,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":350,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700506800,"sunrise":1700492005,"sunset":1700527805,"temp":286.48,"feels_like":285.12,"pressure":1027,"humidity":48,"dew_point":275.71,"uvi":2.26,"clouds":0,"visibility":10000,"wind_speed":4.12,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700510400,"sunrise":1700492005,"sunset":1700527805,"temp":288.23,"feels_like":287.02,"pressure":1026,"humidity":47,"dew_point":277.01,"uvi":2.6,"clouds":0,"visibility":10000,"wind_speed":4.12,"wind_deg":170,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700514000,"sunrise":1700492005,"sunset":1700527805,"temp":289.57,"feels_like":288.49,"pressure":1026,"humidity":47,"dew_point":278.24,"uvi":2.38,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":200,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700517600,"sunrise":1700492005,"sunset":1700527805,"temp":290.43,"feels_like":289.39,"pressure":1025,"humidity":45,"dew_point":278.4,"uvi":1.68,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":230,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"data":[{"dt":1700521200,"sunrise":1700492005,"sunset":1700527805,"temp":290.43,"feels_like":289.36,"pressure":1025,"humidity":44,"dew_point":278.08,"uvi":0.87,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":130,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# Saving weather info in file ../Data/Inputs/weather_Sacramento_2023-11-20.csv
#                     dt             timezone  timezone_offset  \
# 0  2023-11-20 00:00:00  America/Los_Angeles           -28800
# 1  2023-11-20 01:00:00  America/Los_Angeles           -28800
# 2  2023-11-20 02:00:00  America/Los_Angeles           -28800
# 3  2023-11-20 03:00:00  America/Los_Angeles           -28800
# 4  2023-11-20 04:00:00  America/Los_Angeles           -28800
#
#                sunrise               sunset    temp  feels_like  pressure  \
# 0  2023-11-19 14:52:19  2023-11-20 00:50:41  288.57      287.34      1028
# 1  2023-11-19 14:52:19  2023-11-20 00:50:41  287.39      286.15      1027
# 2  2023-11-19 14:52:19  2023-11-20 00:50:41  286.37      285.03      1027
# 3  2023-11-19 14:52:19  2023-11-20 00:50:41  286.00      284.72      1027
# 4  2023-11-19 14:52:19  2023-11-20 00:50:41  285.69      284.44      1027
#
#    humidity  dew_point   uvi  clouds  visibility  wind_speed  wind_deg  \
# 0        45     276.71  0.25       0       10000        6.17       320
# 1        49     276.84  0.00       0       10000        7.72       330
# 2        49     275.90  0.00       0       10000        6.69       340
# 3        53     276.67  0.00       0       10000        7.72       340
# 4        55     276.90  0.00       0       10000        7.20       320
#
#    wind_gust                                            weather
# 0       10.8  [{'id': 800, 'main': 'Clear', 'description': '...
# 1        NaN  [{'id': 800, 'main': 'Clear', 'description': '...
# 2        NaN  [{'id': 800, 'main': 'Clear', 'description': '...
# 3        NaN  [{'id': 800, 'main': 'Clear', 'description': '...
# 4       10.8  [{'id': 800, 'main': 'Clear', 'description': '...

# %%
file_namepath = '../Data/Inputs/weather_{}_{}.csv'.format(sites[site_number]['Name'], date_str.split()[0])
print("Saving weather info in file {}".format(file_namepath))
df_day_weather.to_csv(file_namepath, index = False)
# Out:
# Saving weather info in file ../Data/Inputs/weather_San Francisco_2023-10-16.csv

# %% [markdown]
# ## Irradiance (NOT FREE)

# %%
# Typical API call
#https://api.openweathermap.org/energy/1.0/solar/data?lat=60.45&lon=-38.67&date=2023-03-30&tz=+03:00&appid={API key}

# %%
def add_hour_to_date(date, n_hour):
  date = date + timedelta(hours = int(n_hour))
  return date

# %%
def req_irradiance(api_key, lon, lat, date):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/energy/1.0/solar/data?'
  params = {
      'appid': api_key,
      'lat': lat,
      'lon': lon,
      'date': date
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
'''date = datetime.strptime('2022-01-01', '%Y-%m-%d')
date_str = date.strftime('%Y-%m-%d')

resp = req_irradiance(api_key= api_key, lon=longitude, lat=latitude, date=date_str)
json_data = json.loads(resp.text)

df_irr_day = pd.json_normalize(json_data['irradiance']['hourly'])

df_irr_day.insert(0, 'dt_local', 0)
df_irr_day.insert(1, 'gmt_difference', json_data['tz'])
df_irr_day
'''
# Out:
# {"lat":21.446911,"lon":-158.188736,"date":"2022-01-01","tz":"-10:00","sunrise":"2022-01-01T07:10:30","sunset":"2022-01-01T18:02:34","irradiance":{"daily":[{"clear_sky":{"ghi":4682.08,"dni":7721.49,"dhi":767.91},"cloudy_sky":{"ghi":3455.0,"dni":4089.36,"dhi":1228.25}}],"hourly":[{"hour":0,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":1,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":2,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":3,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":4,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":5,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":6,"clear_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0},"cloudy_sky":{"ghi":0.0,"dni":0.0,"dhi":0.0}},{"hour":7,"clear_sky"
# {'lat': 21.446911,
#  'lon': -158.188736,
#  'date': '2022-01-01',
#  'tz': '-10:00',
#  'sunrise': '2022-01-01T07:10:30',
#  'sunset': '2022-01-01T18:02:34',
#  'irradiance': {'daily': [{'clear_sky': {'ghi': 4682.08,
#      'dni': 7721.49,
#      'dhi': 767.91},
#     'cloudy_sky': {'ghi': 3455.0, 'dni': 4089.36, 'dhi': 1228.25}}],
#   'hourly': [{'hour': 0,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 1,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 2,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 3,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 4,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 5,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 6,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 7,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 8,
#     'clear_sky': {'ghi': 36.84, 'dni': 325.74, 'dhi': 15.66},
#     'cloudy_sky': {'ghi': 20.69, 'dni': 153.44, 'dhi': 10.72}},
#    {'hour': 9,
#     'clear_sky': {'ghi': 211.2, 'dni': 582.41, 'dhi': 57.1},
#     'cloudy_sky': {'ghi': 127.29, 'dni': 225.96, 'dhi': 67.5}},
#    {'hour': 10,
#     'clear_sky': {'ghi': 406.22, 'dni': 739.24, 'dhi': 76.94},
#     'cloudy_sky': {'ghi': 309.92, 'dni': 465.68, 'dhi': 102.49}},
#    {'hour': 11,
#     'clear_sky': {'ghi': 569.8, 'dni': 824.11, 'dhi': 86.44},
#     'cloudy_sky': {'ghi': 467.93, 'dni': 593.69, 'dhi': 119.72}},
#    {'hour': 12,
#     'clear_sky': {'ghi': 677.69, 'dni': 863.4, 'dhi': 92.25},
#     'cloudy_sky': {'ghi': 471.64, 'dni': 408.09, 'dhi': 194.93}},
#    {'hour': 13,
#     'clear_sky': {'ghi': 719.57, 'dni': 876.63, 'dhi': 93.87},
#     'cloudy_sky': {'ghi': 488.89, 'dni': 476.45, 'dhi': 148.82}},
#    {'hour': 14,
#     'clear_sky': {'ghi': 690.38, 'dni': 862.51, 'dhi': 94.22},
#     'cloudy_sky': {'ghi': 574.22, 'dni': 629.51, 'dhi': 139.11}},
#    {'hour': 15,
#     'clear_sky': {'ghi': 597.65, 'dni': 832.86, 'dhi': 88.05},
#     'cloudy_sky': {'ghi': 410.79, 'dni': 407.35, 'dhi': 161.55}},
#    {'hour': 16,
#     'clear_sky': {'ghi': 447.77, 'dni': 767.96, 'dhi': 78.19},
#     'cloudy_sky': {'ghi': 389.46, 'dni': 510.56, 'dhi': 143.75}},
#    {'hour': 17,
#     'clear_sky': {'ghi': 257.58, 'dni': 636.79, 'dhi': 61.23},
#     'cloudy_sky': {'ghi': 156.96, 'dni': 154.86, 'dhi': 109.21}},
#    {'hour': 18,
#     'clear_sky': {'ghi': 67.38, 'dni': 409.84, 'dhi': 23.96},
#     'cloudy_sky': {'ghi': 37.21, 'dni': 63.78, 'dhi': 30.45}},
#    {'hour': 19,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 20,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 21,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 22,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}},
#    {'hour': 23,
#     'clear_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0},
#     'cloudy_sky': {'ghi': 0.0, 'dni': 0.0, 'dhi': 0.0}}]}}

# %% [markdown]
# ## Irradiance by dates (NOT SUSCRIBED)

# %%
# Example:
#https://api.openweathermap.org/data/2.5/solar_radiation/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={API key}

# %%
sites
# Out:
# {1: {'Name': 'San Antonio',
#   'Latitude': 35.05,
#   'Longitude': -106.53,
#   'Timezone': 'GMT+7',
#   'Elevation': 1657.0},
#  2: {'Name': 'Waianae',
#   'Latitude': 21.446911,
#   'Longitude': -158.188736,
#   'Timezone': 'Pacific/Honolulu',
#   'Elevation': 4.0},
#  3: {'Name': 'Amity',
#   'Latitude': 45.114559,
#   'Longitude': -123.204903,
#   'Timezone': 'America/Los Angeles',
#   'Elevation': 50.0},
#  4: {'Name': 'Donalsonville',
#   'Latitude': 31.044241,
#   'Longitude': -84.879128,
#   'Timezone': 'America/New York',
#   'Elevation': 0.0}}

# %%
def req_irradiance_hist(api_key, lon, lat, start_date, end_date):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/data/2.5/solar_radiation/history?'
  params = {
      'appid': api_key,
      'lat': lat,
      'lon': lon,
      'start': start_date,
      'end':end_date
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
site_number = 2
latitude = sites[site_number]['Latitude']
longitude = sites[site_number]['Longitude']

start_utc = datetime.strptime('2022-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')
end_utc = datetime.strptime('2022-01-06 23:00:00', '%Y-%m-%d %H:%M:%S')

start_timestamp = start_utc.replace(tzinfo=timezone.utc).timestamp()
end_timestamp = end_utc.replace(tzinfo=timezone.utc).timestamp()

end_timestamp
# Out:
# 1641510000.0

# %%
resp = req_irradiance_hist(api_key, lon=longitude, lat=latitude,
                      start_date=int(start_timestamp), end_date=int(end_timestamp))
# Out:
# Data acquisition failed due to 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/solar_radiation/history?appid=499817a2d0296f45499bb26bf6039e01&lat=21.446911&lon=-158.188736&start=1640995200&end=1641510000

# %%
df_weather = pd.DataFrame()
df_week = pd.DataFrame()

start = start_utc
end = end_utc

#for i in range(1, 36):
for i in range(1, 2):
  #start = start + timedelta(days = i*i)
  #end = end + timedelta(days = i*i)
  print(start, end)
  start_timestamp = start.replace(tzinfo=timezone.utc).timestamp()
  end_timestamp = end.replace(tzinfo=timezone.utc).timestamp()
  start = end  + timedelta(hours = 1)
  end = end + timedelta(days = 6)

  resp = req_hist_data(api_key= api_key, lon=longitude, lat=latitude,
                      start_date=int(start_timestamp), end_date=int(end_timestamp))

  json_data = json.loads(resp.text)

  df_week = pd.json_normalize(json_data['list'])
  #change formating of epoch time to UTC
  df_week.dt = df_week.dt.apply(datetime.fromtimestamp)

  #df_weather = df_weather.append(df_week, ignore_index= True)
  df_weather = pd.concat([df_weather, df_week], ignore_index=True)

df_weather
