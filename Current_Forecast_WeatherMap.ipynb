# %% [markdown]
# # Extract Forecast Information from Weather Map
#
# ---
#
#
# By Mauricio Hernandez

# %% [markdown]
# Goal(s):
# - Collect and download forecasting data from a set of locations using the WeatherMap API.

# %% [markdown]
# ---
# See documentation at: See documentation at: https://openweathermap.org/api/one-call-3

# %%
#Import libraries
import requests
import pandas as pd
import os
import json
import glob
from pathlib import Path
#import datetime
import time
from datetime import timezone
from datetime import datetime
from google.colab import drive
from datetime import timedelta

# %%
#Connect to google drive
drive.mount('/content/gdrive')
#access path where notebook is stored
path = "/content/gdrive/MyDrive/Lumiere Program/Niharika Yalla/Code/"
#Change the working directory to the folder
os.chdir(path)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Create dictionary with sites information

# %%
sites = { 1: {'Name': 'San Francisco', 'Latitude': 37.7749, 'Longitude': -122.4194, 'Timezone': 'America/Los Angeles', 'Elevation': 52.0},
          2: {'Name': 'San Diego', 'Latitude': 32.7157, 'Longitude': -117.1611, 'Timezone': 'America/Los Angeles', 'Elevation': 19.0},
          3: {'Name': 'Los Angeles', 'Latitude': 34.0549, 'Longitude': -118.2426, 'Timezone': 'America/Los Angeles', 'Elevation': 89.0},
          4: {'Name': 'Sacramento', 'Latitude': 38.5816, 'Longitude': -121.4944, 'Timezone': 'America/Los Angeles', 'Elevation': 8.0}
         }

# %%
#Read API_key
# In a text file write NREL api key in the first line and save it
with open('../Data/Inputs/WeatherMap_APIKey') as f:
    line = f.readline()
api_key = line.replace('\n', '')

# %% [markdown]
# ## Download Forecast Data

# %%
def convert_timestamp_to_text(datestamp, date_format):
  date_str = datetime.utcfromtimestamp(datestamp).strftime(date_format)
  return date_str

# %% [markdown]
# ### 3 Hour Resolution Forecast - FREE

# %%
#Example of API call
#api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API key}

# %%
def req_forecast_3hr(api_key, lon, lat):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/data/2.5/forecast?'
  params = {
      'appid': api_key,
      'lat': lat,
      'lon': lon
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
site_number = 1
date_format = '%Y-%m-%d %H:%M:%S'

resp = req_forecast_3hr(api_key, lat = sites[site_number]['Latitude'], lon = sites[site_number]['Longitude'])
json_data = json.loads(resp.text)

df_forecast = pd.json_normalize(json_data['list'])
df_forecast.insert(1, 'dt_machine', 0)
df_forecast['dt_machine'] = df_forecast['dt']
df_forecast['dt'] = df_forecast.apply(lambda x: convert_timestamp_to_text(x['dt'], date_format), axis =1)
df_forecast.drop(columns=['dt_txt'], axis =1, inplace=True)
df_forecast.head()
# Out:
# {"cod":"200","message":0,"cnt":40,"list":[{"dt":1700168400,"main":{"temp":289.97,"feels_like":289.61,"temp_min":289.97,"temp_max":290.54,"pressure":1015,"sea_level":1015,"grnd_level":1012,"humidity":73,"temp_kf":-0.57},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"clouds":{"all":80},"wind":{"speed":2.91,"deg":47,"gust":3.74},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2023-11-16 21:00:00"},{"dt":1700179200,"main":{"temp":289.95,"feels_like":289.62,"temp_min":289.95,"temp_max":290.09,"pressure":1014,"sea_level":1014,"grnd_level":1011,"humidity":74,"temp_kf":-0.14},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"clouds":{"all":88},"wind":{"speed":1.05,"deg":44,"gust":1.87},"visibility":10000,"pop":0.27,"rain":{"3h":1.01},"sys":{"pod":"d"},"dt_txt":"2023-11-17 00:00:00"},{"dt":1700190000,"main":{"temp":288.5,"feels_like":288.34,"temp_min":288.5,"temp_max":288.5,"pressure":1015,"sea_level":1015,"grnd_level":1013,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-69847849e973> in <cell line: 10>()
#       8 df_forecast.insert(1, 'dt_machine', 0)
#       9 df_forecast['dt_machine'] = df_forecast['dt']
# ---> 10 df_forecast['dt'] = df_forecast.apply(lambda x: convert_timestamp_to_text(x['dt'], date_format), axis =1)
#      11 df_forecast.drop(columns=['dt_txt'], axis =1, inplace=True)
#      12 df_forecast.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-6-69847849e973> in <lambda>(x)
#       8 df_forecast.insert(1, 'dt_machine', 0)
#       9 df_forecast['dt_machine'] = df_forecast['dt']
# ---> 10 df_forecast['dt'] = df_forecast.apply(lambda x: convert_timestamp_to_text(x['dt'], date_format), axis =1)
#      11 df_forecast.drop(columns=['dt_txt'], axis =1, inplace=True)
#      12 df_forecast.head()
#
# NameError: name 'convert_timestamp_to_text' is not defined

# %%
#Save file
#results_filename = './outputs/forecast_{}_{}_3hr.csv'.format(sites[site_number]['name'], datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
results_filename = '../Data/Outputs/forecast_{}_{}_3hr.csv'.format(sites[site_number]['Name'], datetime.now().strftime("%m-%d-%Y_%H-%M"))
print('Saving file: {} '.format(results_filename))
df_forecast.to_csv(results_filename, index = False)
# Out:
# Saving file: ../Data/Outputs/forecast_San Francisco_11-06-2023_02-57_3hr.csv

# %% [markdown]
# ## Hourly Forecast
#
# > Getting this data is not free, but we have 1,000 calls per day for free.

# %%
#Example call:
# https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}
def req_forecast(api_key, lon, lat):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/data/3.0/onecall?'
  params = {
      'appid': api_key,
      'exclude':'alerts',
      'lat': lat,
      'lon': lon
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
#Select site
site_number = 4
sites[site_number]

resp = req_forecast(api_key, lat = sites[site_number]['Latitude'], lon = sites[site_number]['Longitude'])
json_data = json.loads(resp.text)

date_format = '%Y-%m-%d %H:%M:%S'

df_forecast_current = pd.json_normalize(json_data['current'])
df_forecast_hr = pd.json_normalize(json_data['hourly'])
df_forecast_day = pd.json_normalize(json_data['daily'])

#df_forecast_hr.insert(1, 'dt_machine', 0)
df_forecast_hr.rename(columns={"dt": "dt_machine"}, inplace = True)
df_forecast_hr.insert(0, 'dt', 0)
df_forecast_hr.insert(2, 'timezone', json_data['timezone'])
df_forecast_hr.insert(3, 'timezone_offset', json_data['timezone_offset'])

df_forecast_hr['dt'] = df_forecast_hr.apply(lambda x: convert_timestamp_to_text(x['dt_machine'], date_format), axis =1)

results_filename = '../Data/Inputs/current_forecast_{}_{}_hourly.csv'.format(sites[site_number]['Name'], datetime.now().strftime("%m-%d-%Y_%H-%M"))

print('Saving file: {} '.format(results_filename))
df_forecast_hr.to_csv(results_filename, index = False)
# Out:
# {"lat":38.5816,"lon":-121.4944,"timezone":"America/Los_Angeles","timezone_offset":-28800,"current":{"dt":1700751928,"sunrise":1700751399,"sunset":1700786907,"temp":278.97,"feels_like":277.98,"pressure":1014,"humidity":96,"dew_point":278.38,"uvi":0,"clouds":20,"visibility":8047,"wind_speed":1.54,"wind_deg":300,"weather":[{"id":701,"main":"Mist","description":"mist","icon":"50d"}]},"minutely":[{"dt":1700751960,"precipitation":0},{"dt":1700752020,"precipitation":0},{"dt":1700752080,"precipitation":0},{"dt":1700752140,"precipitation":0},{"dt":1700752200,"precipitation":0},{"dt":1700752260,"precipitation":0},{"dt":1700752320,"precipitation":0},{"dt":1700752380,"precipitation":0},{"dt":1700752440,"precipitation":0},{"dt":1700752500,"precipitation":0},{"dt":1700752560,"precipitation":0},{"dt":1700752620,"precipitation":0},{"dt":1700752680,"precipitation":0},{"dt":1700752740,"precipitation":0},{"dt":1700752800,"precipitation":0},{"dt":1700752860,"precipitation":0},{"dt":1700752920,"precipitati
# Saving file: ../Data/Inputs/current_forecast_Sacramento_11-23-2023_15-05_hourly.csv

# %% [markdown]
# ## Historical Forecast
#
# **TODO: Change this, this is in fact historical weather data**

# %%
#https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={time}&appid={API key}

def req_hist_forecast(api_key, lon, lat, datetime):
  # If the request is successful, a CSV file with the requested info will be send to the email sent as parameter
  api_url = 'https://api.openweathermap.org/data/3.0/onecall//timemachine?'
  params = {
      'appid': api_key,
      'exclude':'alerts',
      'lat': lat,
      'lon': lon,
      'dt': datetime,
  }

  try:
      (r := requests.get(api_url, params=params)).raise_for_status()
      print(r.text[0:1000])
  except Exception as e:
      print(f'Data acquisition failed due to {e}')
  return r

# %%
start_utc = datetime.strptime('2023-10-15 00:00:00', '%Y-%m-%d %H:%M:%S')
end_utc = datetime.strptime('2022-10-26 23:00:00', '%Y-%m-%d %H:%M:%S')

#resp = req_hist_forecast(api_key, lat = sites[site_number]['latitude'], lon = sites[site_number]['longitude'], datetime = '1687102209')
#json_hist_data = json.loads(resp.text)

# %%
df_hist_forecast_hr = pd.DataFrame()
df_forec_period = pd.DataFrame()

#start_datetime = datetime.strptime('2023-06-19 00:00:00', '%Y-%m-%d %H:%M:%S')

start_datetime = datetime.strptime('2023-10-15 00:00:00', '%Y-%m-%d %H:%M:%S')
end_datetime = datetime.strptime('2023-10-31 23:00:00', '%Y-%m-%d %H:%M:%S')

diff_time = end_datetime - start_datetime
n_hours = diff_time.days*24 + diff_time.seconds/3600

hist_datetime = start_datetime

for i in range(0, int(n_hours)):
  #start = start + timedelta(days = i*i)
  #end = end + timedelta(days = i*i)

  hist_epoch_timestamp = hist_datetime.replace(tzinfo=timezone.utc).timestamp()
  print(hist_datetime)

  #resp = req_hist_forecast(api_key= api_key, lon=longitude, lat=latitude,
  #                    datetime=int(hist_epoch_timestamp))

  resp = req_hist_forecast(api_key, lat = sites[site_number]['latitude'], lon = sites[site_number]['longitude'], datetime = int(hist_epoch_timestamp))
  json_hist_data = json.loads(resp.text)

  df_hist_forecast_hr = pd.json_normalize(json_hist_data['data'])

  #json_data = json.loads(resp.text)

  #df_week = pd.json_normalize(json_data['list'])
  #change formating of epoch time to UTC

  #df_week.dt = df_week.dt.apply(datetime.fromtimestamp)

  #df_weather = df_weather.append(df_week, ignore_index= True)
  #df_weather = pd.concat([df_weather, df_forec_period], ignore_index=True)
  hist_datetime = hist_datetime  + timedelta(hours = 1)

  date_format = '%Y-%m-%d %H:%M:%S'

  #df_forecast_hr.insert(1, 'dt_machine', 0)
  df_hist_forecast_hr.rename(columns={"dt": "dt_machine"}, inplace = True)
  df_hist_forecast_hr.insert(0, 'dt', 0)
  df_hist_forecast_hr.insert(2, 'timezone', json_hist_data['timezone'])
  df_hist_forecast_hr.insert(3, 'timezone_offset', json_hist_data['timezone_offset'])

  df_hist_forecast_hr['dt'] = df_hist_forecast_hr.apply(lambda x: convert_timestamp_to_text(x['dt_machine'], date_format), axis =1)

  #df_weather = df_weather.append(df_hist_forecast_hr, ignore_index= True)
  df_forec_period = pd.concat([df_forec_period, df_hist_forecast_hr], ignore_index=True)

results_filename = './outputs/current_weather_forecasts/forecast_{}_{}_to{}_hr.csv'.format(sites[site_number]['name'], start_datetime.strftime('%Y-%m-%d_%H-%M'), end_datetime.strftime('%Y-%m-%d_%H-%M') )

print('Saving file: {} '.format(results_filename))
df_forec_period.to_csv(results_filename, index = False)
# Out:
# 2023-06-15 00:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686787200,"sunrise":1686757815,"sunset":1686806157,"temp":299.63,"feels_like":299.63,"pressure":1018,"humidity":56,"dew_point":290.15,"clouds":75,"visibility":10000,"wind_speed":4.63,"wind_deg":80,"wind_gust":8.23,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-15 01:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686790800,"sunrise":1686757815,"sunset":1686806157,"temp":300.31,"feels_like":301.13,"pressure":1017,"humidity":56,"dew_point":290.78,"clouds":75,"visibility":10000,"wind_speed":7.72,"wind_deg":90,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-15 02:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686794400,"sunrise":1686757815,"sunset":1686806157,"temp":299.65,"feels_like":299.65,"pressure":1017,"humidity":58,"dew_point":290.72,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":90,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":0.63}}]}
# 2023-06-15 03:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686798000,"sunrise":1686757815,"sunset":1686806157,"temp":299.54,"feels_like":299.54,"pressure":1017,"humidity":61,"dew_point":291.42,"clouds":40,"visibility":10000,"wind_speed":6.17,"wind_deg":70,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":0.63}}]}
# 2023-06-15 04:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686801600,"sunrise":1686757815,"sunset":1686806157,"temp":299.41,"feels_like":299.41,"pressure":1017,"humidity":62,"dew_point":291.55,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":100,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":0.63}}]}
# 2023-06-15 05:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686805200,"sunrise":1686757815,"sunset":1686806157,"temp":298.69,"feels_like":298.94,"pressure":1018,"humidity":63,"dew_point":291.13,"clouds":40,"visibility":10000,"wind_speed":4.12,"wind_deg":70,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-15 06:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686808800,"sunrise":1686757815,"sunset":1686806157,"temp":298.45,"feels_like":298.73,"pressure":1018,"humidity":65,"dew_point":291.4,"clouds":20,"visibility":10000,"wind_speed":3.09,"wind_deg":80,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}]}]}
# 2023-06-15 07:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686812400,"sunrise":1686757815,"sunset":1686806157,"temp":298.21,"feels_like":298.57,"pressure":1019,"humidity":69,"dew_point":292.13,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":90,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}]}]}
# 2023-06-15 08:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686816000,"sunrise":1686757815,"sunset":1686806157,"temp":297.83,"feels_like":298.21,"pressure":1019,"humidity":71,"dew_point":292.22,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-15 09:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686819600,"sunrise":1686757815,"sunset":1686806157,"temp":297.83,"feels_like":298.21,"pressure":1019,"humidity":71,"dew_point":292.22,"clouds":40,"visibility":10000,"wind_speed":1.54,"wind_deg":90,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-15 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686823200,"sunrise":1686844222,"sunset":1686892574,"temp":297.34,"feels_like":297.93,"pressure":1019,"humidity":81,"dew_point":293.87,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":270,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-15 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686826800,"sunrise":1686844222,"sunset":1686892574,"temp":297.21,"feels_like":297.71,"pressure":1018,"humidity":78,"dew_point":293.14,"clouds":75,"visibility":10000,"wind_speed":1.54,"wind_deg":300,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-15 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686830400,"sunrise":1686844222,"sunset":1686892574,"temp":297.21,"feels_like":297.71,"pressure":1017,"humidity":78,"dew_point":293.14,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-15 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686834000,"sunrise":1686844222,"sunset":1686892574,"temp":297.1,"feels_like":297.67,"pressure":1017,"humidity":81,"dew_point":293.64,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":330,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}]}]}
# 2023-06-15 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686837600,"sunrise":1686844222,"sunset":1686892574,"temp":297.14,"feels_like":297.71,"pressure":1017,"humidity":81,"dew_point":293.68,"clouds":75,"visibility":10000,"wind_speed":1.54,"wind_deg":30,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.13}}]}
# 2023-06-15 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686841200,"sunrise":1686844222,"sunset":1686892574,"temp":297.14,"feels_like":297.71,"pressure":1017,"humidity":81,"dew_point":293.68,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.13}}]}
# 2023-06-15 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686844800,"sunrise":1686844222,"sunset":1686892574,"temp":296.89,"feels_like":297.57,"pressure":1017,"humidity":86,"dew_point":294.41,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":0.13}}]}
# 2023-06-15 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686848400,"sunrise":1686844222,"sunset":1686892574,"temp":297.83,"feels_like":298.39,"pressure":1018,"humidity":78,"dew_point":293.74,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":300,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-15 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686852000,"sunrise":1686844222,"sunset":1686892574,"temp":298.43,"feels_like":298.76,"pressure":1018,"humidity":67,"dew_point":291.87,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":30,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-15 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686855600,"sunrise":1686844222,"sunset":1686892574,"temp":298.55,"feels_like":298.84,"pressure":1018,"humidity":65,"dew_point":291.5,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":80,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-15 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686859200,"sunrise":1686844222,"sunset":1686892574,"temp":299.74,"feels_like":299.74,"pressure":1018,"humidity":60,"dew_point":291.34,"clouds":100,"visibility":10000,"wind_speed":3.6,"wind_deg":80,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-15 21:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686862800,"sunrise":1686844222,"sunset":1686892574,"temp":299.51,"feels_like":299.51,"pressure":1018,"humidity":67,"dew_point":292.89,"clouds":75,"visibility":10000,"wind_speed":4.63,"wind_deg":70,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-15 22:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686866400,"sunrise":1686844222,"sunset":1686892574,"temp":299.51,"feels_like":299.51,"pressure":1018,"humidity":65,"dew_point":292.4,"clouds":100,"visibility":10000,"wind_speed":6.17,"wind_deg":90,"wind_gust":8.23,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-15 23:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686870000,"sunrise":1686844222,"sunset":1686892574,"temp":299.23,"feels_like":299.23,"pressure":1017,"humidity":76,"dew_point":294.67,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":90,"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10d"},{"id":701,"main":"Mist","description":"mist","icon":"50d"}]}]}
# 2023-06-16 00:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686873600,"sunrise":1686844222,"sunset":1686892574,"temp":299.57,"feels_like":299.57,"pressure":1017,"humidity":67,"dew_point":292.95,"clouds":100,"visibility":10000,"wind_speed":4.12,"wind_deg":60,"wind_gust":7.72,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-16 01:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686877200,"sunrise":1686844222,"sunset":1686892574,"temp":299.46,"feels_like":299.46,"pressure":1017,"humidity":67,"dew_point":292.84,"clouds":100,"visibility":10000,"wind_speed":4.63,"wind_deg":80,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-16 02:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686880800,"sunrise":1686844222,"sunset":1686892574,"temp":299.1,"feels_like":299.1,"pressure":1016,"humidity":61,"dew_point":291,"clouds":100,"visibility":10000,"wind_speed":5.14,"wind_deg":60,"wind_gust":8.75,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-16 03:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686884400,"sunrise":1686844222,"sunset":1686892574,"temp":298.99,"feels_like":299.22,"pressure":1016,"humidity":61,"dew_point":290.9,"clouds":100,"visibility":10000,"wind_speed":4.12,"wind_deg":120,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-16 04:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686888000,"sunrise":1686844222,"sunset":1686892574,"temp":298.98,"feels_like":299.24,"pressure":1016,"humidity":62,"dew_point":291.15,"clouds":100,"visibility":10000,"wind_speed":3.6,"wind_deg":60,"wind_gust":8.23,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-16 05:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686891600,"sunrise":1686844222,"sunset":1686892574,"temp":298.37,"feels_like":298.64,"pressure":1017,"humidity":65,"dew_point":291.33,"clouds":100,"visibility":10000,"wind_speed":4.12,"wind_deg":40,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-16 06:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686895200,"sunrise":1686844222,"sunset":1686892574,"temp":298.18,"feels_like":298.44,"pressure":1016,"humidity":65,"dew_point":291.15,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-16 07:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686898800,"sunrise":1686844222,"sunset":1686892574,"temp":297.89,"feels_like":298.35,"pressure":1018,"humidity":74,"dew_point":292.94,"clouds":40,"visibility":10000,"wind_speed":2.57,"wind_deg":60,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-16 08:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686902400,"sunrise":1686844222,"sunset":1686892574,"temp":297.87,"feels_like":298.2,"pressure":1017,"humidity":69,"dew_point":291.8,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-16 09:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686906000,"sunrise":1686844222,"sunset":1686892574,"temp":297.86,"feels_like":298.24,"pressure":1018,"humidity":71,"dew_point":292.25,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-16 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686909600,"sunrise":1686930629,"sunset":1686978991,"temp":297.62,"feels_like":298.11,"pressure":1017,"humidity":76,"dew_point":293.11,"clouds":75,"visibility":9656,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50n"}]}]}
# 2023-06-16 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686913200,"sunrise":1686930629,"sunset":1686978991,"temp":297.59,"feels_like":298,"pressure":1016,"humidity":73,"dew_point":292.44,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-16 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686916800,"sunrise":1686930629,"sunset":1686978991,"temp":297.49,"feels_like":297.96,"pressure":1016,"humidity":76,"dew_point":292.99,"clouds":100,"visibility":10000,"wind_speed":1.54,"wind_deg":60,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}]}]}
# 2023-06-16 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686920400,"sunrise":1686930629,"sunset":1686978991,"temp":297.49,"feels_like":297.96,"pressure":1016,"humidity":76,"dew_point":292.99,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":70,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-16 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686924000,"sunrise":1686930629,"sunset":1686978991,"temp":297.29,"feels_like":297.8,"pressure":1015,"humidity":78,"dew_point":293.21,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":40,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-16 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686927600,"sunrise":1686930629,"sunset":1686978991,"temp":297.18,"feels_like":297.75,"pressure":1015,"humidity":81,"dew_point":293.72,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-16 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686931200,"sunrise":1686930629,"sunset":1686978991,"temp":297.05,"feels_like":297.66,"pressure":1016,"humidity":83,"dew_point":293.99,"clouds":100,"visibility":8047,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":701,"main":"Mist","description":"mist","icon":"50d"}]}]}
# 2023-06-16 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686934800,"sunrise":1686930629,"sunset":1686978991,"temp":297.91,"feels_like":298.35,"pressure":1015,"humidity":73,"dew_point":292.74,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-16 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686938400,"sunrise":1686930629,"sunset":1686978991,"temp":298.14,"feels_like":298.5,"pressure":1017,"humidity":69,"dew_point":292.06,"clouds":75,"visibility":10000,"wind_speed":1.54,"wind_deg":100,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-16 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686942000,"sunrise":1686930629,"sunset":1686978991,"temp":298.6,"feels_like":298.77,"pressure":1017,"humidity":60,"dew_point":290.27,"clouds":75,"visibility":10000,"wind_speed":3.6,"wind_deg":90,"wind_gust":8.23,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-16 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686945600,"sunrise":1686930629,"sunset":1686978991,"temp":299.77,"feels_like":299.77,"pressure":1017,"humidity":58,"dew_point":290.83,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":120,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-16 21:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686949200,"sunrise":1686930629,"sunset":1686978991,"temp":299.79,"feels_like":299.79,"pressure":1017,"humidity":57,"dew_point":290.57,"clouds":100,"visibility":10000,"wind_speed":5.66,"wind_deg":70,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-16 22:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686952800,"sunrise":1686930629,"sunset":1686978991,"temp":299.89,"feels_like":300.61,"pressure":1017,"humidity":55,"dew_point":290.1,"clouds":100,"visibility":10000,"wind_speed":5.66,"wind_deg":80,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-16 23:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686956400,"sunrise":1686930629,"sunset":1686978991,"temp":300.49,"feels_like":300.69,"pressure":1016,"humidity":47,"dew_point":288.19,"clouds":75,"visibility":10000,"wind_speed":6.69,"wind_deg":110,"wind_gust":9.26,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-17 00:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686960000,"sunrise":1686930629,"sunset":1686978991,"temp":300.36,"feels_like":300.84,"pressure":1016,"humidity":51,"dew_point":289.35,"clouds":100,"visibility":10000,"wind_speed":7.2,"wind_deg":80,"wind_gust":9.26,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-17 01:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686963600,"sunrise":1686930629,"sunset":1686978991,"temp":300.49,"feels_like":300.57,"pressure":1016,"humidity":45,"dew_point":287.52,"clouds":40,"visibility":10000,"wind_speed":8.23,"wind_deg":90,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-17 02:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686967200,"sunrise":1686930629,"sunset":1686978991,"temp":299.95,"feels_like":300.38,"pressure":1015,"humidity":50,"dew_point":288.66,"clouds":75,"visibility":10000,"wind_speed":7.2,"wind_deg":90,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-17 03:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686970800,"sunrise":1686930629,"sunset":1686978991,"temp":299.84,"feels_like":300.45,"pressure":1015,"humidity":53,"dew_point":289.47,"clouds":0,"visibility":10000,"wind_speed":5.14,"wind_deg":90,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-17 04:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686974400,"sunrise":1686930629,"sunset":1686978991,"temp":299.6,"feels_like":299.6,"pressure":1015,"humidity":58,"dew_point":290.67,"clouds":75,"visibility":10000,"wind_speed":4.63,"wind_deg":70,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-17 05:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686978000,"sunrise":1686930629,"sunset":1686978991,"temp":298.43,"feels_like":298.82,"pressure":1016,"humidity":69,"dew_point":292.34,"clouds":0,"visibility":10000,"wind_speed":4.12,"wind_deg":70,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-17 06:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686981600,"sunrise":1686930629,"sunset":1686978991,"temp":298.27,"feels_like":298.64,"pressure":1016,"humidity":69,"dew_point":292.18,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":100,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-17 07:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686985200,"sunrise":1686930629,"sunset":1686978991,"temp":298.15,"feels_like":298.48,"pressure":1017,"humidity":68,"dew_point":291.84,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-17 08:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686988800,"sunrise":1686930629,"sunset":1686978991,"temp":297.89,"feels_like":298.22,"pressure":1017,"humidity":69,"dew_point":291.82,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.56}}]}
# 2023-06-17 09:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686992400,"sunrise":1686930629,"sunset":1686978991,"temp":297.39,"feels_like":297.91,"pressure":1017,"humidity":78,"dew_point":293.31,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.56}}]}
# 2023-06-17 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686996000,"sunrise":1687017038,"sunset":1687065406,"temp":297.39,"feels_like":297.91,"pressure":1017,"humidity":78,"dew_point":293.31,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.56}}]}
# 2023-06-17 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1686999600,"sunrise":1687017038,"sunset":1687065406,"temp":297.09,"feels_like":297.58,"pressure":1016,"humidity":78,"dew_point":293.02,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-17 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687003200,"sunrise":1687017038,"sunset":1687065406,"temp":296.96,"feels_like":297.43,"pressure":1016,"humidity":78,"dew_point":292.89,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-17 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687006800,"sunrise":1687017038,"sunset":1687065406,"temp":296.96,"feels_like":297.51,"pressure":1016,"humidity":81,"dew_point":293.5,"clouds":75,"visibility":10000,"wind_speed":2.57,"wind_deg":40,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-17 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687010400,"sunrise":1687017038,"sunset":1687065406,"temp":296.68,"feels_like":297.2,"pressure":1016,"humidity":81,"dew_point":293.23,"clouds":40,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-17 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687014000,"sunrise":1687017038,"sunset":1687065406,"temp":296.66,"feels_like":297.18,"pressure":1016,"humidity":81,"dew_point":293.21,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":310,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-17 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687017600,"sunrise":1687017038,"sunset":1687065406,"temp":296.55,"feels_like":297.06,"pressure":1016,"humidity":81,"dew_point":293.1,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":1}}]}
# 2023-06-17 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687021200,"sunrise":1687017038,"sunset":1687065406,"temp":298,"feels_like":298.34,"pressure":1015,"humidity":69,"dew_point":291.93,"clouds":0,"visibility":10000,"wind_speed":0,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-17 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687024800,"sunrise":1687017038,"sunset":1687065406,"temp":298.23,"feels_like":298.6,"pressure":1017,"humidity":69,"dew_point":292.15,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":120,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-17 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687028400,"sunrise":1687017038,"sunset":1687065406,"temp":298.81,"feels_like":298.92,"pressure":1017,"humidity":57,"dew_point":289.66,"clouds":20,"visibility":10000,"wind_speed":4.12,"wind_deg":140,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-17 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687032000,"sunrise":1687017038,"sunset":1687065406,"temp":299.63,"feels_like":299.63,"pressure":1017,"humidity":61,"dew_point":291.5,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":130,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-17 21:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687035600,"sunrise":1687017038,"sunset":1687065406,"temp":299.76,"feels_like":299.76,"pressure":1017,"humidity":55,"dew_point":289.98,"clouds":75,"visibility":10000,"wind_speed":7.2,"wind_deg":120,"wind_gust":10.29,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-17 22:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687039200,"sunrise":1687017038,"sunset":1687065406,"temp":300,"feels_like":300.43,"pressure":1017,"humidity":50,"dew_point":288.71,"clouds":0,"visibility":10000,"wind_speed":6.69,"wind_deg":130,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-17 23:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687042800,"sunrise":1687017038,"sunset":1687065406,"temp":300.41,"feels_like":300.75,"pressure":1016,"humidity":49,"dew_point":288.77,"clouds":40,"visibility":10000,"wind_speed":7.2,"wind_deg":120,"wind_gust":10.8,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-18 00:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687046400,"sunrise":1687017038,"sunset":1687065406,"temp":300.41,"feels_like":300.69,"pressure":1016,"humidity":48,"dew_point":288.45,"clouds":0,"visibility":10000,"wind_speed":7.72,"wind_deg":130,"wind_gust":10.8,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-18 01:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687050000,"sunrise":1687017038,"sunset":1687065406,"temp":300.41,"feels_like":300.82,"pressure":1015,"humidity":50,"dew_point":289.09,"clouds":0,"visibility":10000,"wind_speed":7.2,"wind_deg":130,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-18 02:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687053600,"sunrise":1687017038,"sunset":1687065406,"temp":300.13,"feels_like":300.21,"pressure":1015,"humidity":44,"dew_point":286.85,"clouds":0,"visibility":10000,"wind_speed":6.17,"wind_deg":100,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-18 03:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687057200,"sunrise":1687017038,"sunset":1687065406,"temp":300,"feels_like":300.49,"pressure":1015,"humidity":51,"dew_point":289.02,"clouds":40,"visibility":10000,"wind_speed":6.69,"wind_deg":90,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-18 04:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687060800,"sunrise":1687017038,"sunset":1687065406,"temp":299.87,"feels_like":300.59,"pressure":1015,"humidity":55,"dew_point":290.08,"clouds":20,"visibility":10000,"wind_speed":5.14,"wind_deg":80,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-18 05:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687064400,"sunrise":1687017038,"sunset":1687065406,"temp":298.8,"feels_like":299.04,"pressure":1016,"humidity":62,"dew_point":290.98,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-18 06:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687068000,"sunrise":1687017038,"sunset":1687065406,"temp":298.45,"feels_like":298.73,"pressure":1017,"humidity":65,"dew_point":291.4,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-18 07:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687071600,"sunrise":1687017038,"sunset":1687065406,"temp":298.21,"feels_like":298.63,"pressure":1017,"humidity":71,"dew_point":292.59,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":60,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-18 08:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687075200,"sunrise":1687017038,"sunset":1687065406,"temp":298.02,"feels_like":298.42,"pressure":1018,"humidity":71,"dew_point":292.4,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.44}}]}
# 2023-06-18 09:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687078800,"sunrise":1687017038,"sunset":1687065406,"temp":297.93,"feels_like":298.37,"pressure":1017,"humidity":73,"dew_point":292.76,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.44}}]}
# 2023-06-18 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687082400,"sunrise":1687103447,"sunset":1687151821,"temp":297.78,"feels_like":298.28,"pressure":1018,"humidity":76,"dew_point":293.27,"clouds":100,"visibility":10000,"wind_speed":3.09,"wind_deg":30,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.44}}]}
# 2023-06-18 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687086000,"sunrise":1687103447,"sunset":1687151821,"temp":297.42,"feels_like":297.94,"pressure":1017,"humidity":78,"dew_point":293.34,"clouds":100,"visibility":10000,"wind_speed":2.57,"wind_deg":40,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-18 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687089600,"sunrise":1687103447,"sunset":1687151821,"temp":297.51,"feels_like":297.91,"pressure":1016,"humidity":73,"dew_point":292.36,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":40,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-18 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687093200,"sunrise":1687103447,"sunset":1687151821,"temp":297.29,"feels_like":297.87,"pressure":1016,"humidity":81,"dew_point":293.82,"clouds":100,"visibility":10000,"wind_speed":1.54,"wind_deg":10,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1}}]}
# 2023-06-18 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687096800,"sunrise":1687103447,"sunset":1687151821,"temp":297.2,"feels_like":297.78,"pressure":1016,"humidity":81,"dew_point":293.74,"clouds":100,"visibility":10000,"wind_speed":2.06,"wind_deg":40,"weather":[{"id":300,"main":"Drizzle","description":"light intensity drizzle","icon":"09n"},{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1.25}}]}
# 2023-06-18 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687100400,"sunrise":1687103447,"sunset":1687151821,"temp":297.2,"feels_like":297.78,"pressure":1016,"humidity":81,"dew_point":293.74,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":30,"weather":[{"id":300,"main":"Drizzle","description":"light intensity drizzle","icon":"09n"},{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":1.25}}]}
# 2023-06-18 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687104000,"sunrise":1687103447,"sunset":1687151821,"temp":297.2,"feels_like":297.78,"pressure":1017,"humidity":81,"dew_point":293.74,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":300,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":1.25}}]}
# 2023-06-18 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687107600,"sunrise":1687103447,"sunset":1687151821,"temp":298.07,"feels_like":298.55,"pressure":1017,"humidity":74,"dew_point":293.12,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":40,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-18 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687111200,"sunrise":1687103447,"sunset":1687151821,"temp":298.51,"feels_like":298.59,"pressure":1017,"humidity":57,"dew_point":289.38,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-18 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687114800,"sunrise":1687103447,"sunset":1687151821,"temp":298.67,"feels_like":298.87,"pressure":1018,"humidity":61,"dew_point":290.6,"clouds":0,"visibility":10000,"wind_speed":3.6,"wind_deg":100,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-18 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687118400,"sunrise":1687103447,"sunset":1687151821,"temp":299.6,"feels_like":299.6,"pressure":1018,"humidity":56,"dew_point":290.12,"clouds":20,"visibility":10000,"wind_speed":4.12,"wind_deg":100,"wind_gust":7.2,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-18 21:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687122000,"sunrise":1687103447,"sunset":1687151821,"temp":299.48,"feels_like":299.48,"pressure":1018,"humidity":59,"dew_point":290.83,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":60,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-18 22:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687125600,"sunrise":1687103447,"sunset":1687151821,"temp":299.72,"feels_like":299.72,"pressure":1017,"humidity":50,"dew_point":288.45,"clouds":100,"visibility":10000,"wind_speed":6.69,"wind_deg":70,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-18 23:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687129200,"sunrise":1687103447,"sunset":1687151821,"temp":300.47,"feels_like":300.68,"pressure":1017,"humidity":47,"dew_point":288.18,"clouds":40,"visibility":10000,"wind_speed":5.14,"wind_deg":70,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-19 00:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687132800,"sunrise":1687103447,"sunset":1687151821,"temp":300.59,"feels_like":300.53,"pressure":1016,"humidity":43,"dew_point":286.91,"clouds":100,"visibility":10000,"wind_speed":5.66,"wind_deg":70,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-19 01:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687136400,"sunrise":1687103447,"sunset":1687151821,"temp":300.47,"feels_like":300.81,"pressure":1016,"humidity":49,"dew_point":288.83,"clouds":0,"visibility":10000,"wind_speed":7.2,"wind_deg":90,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-19 02:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687140000,"sunrise":1687103447,"sunset":1687151821,"temp":300.01,"feels_like":300.27,"pressure":1016,"humidity":47,"dew_point":287.76,"clouds":0,"visibility":10000,"wind_speed":7.2,"wind_deg":90,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-19 03:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687143600,"sunrise":1687103447,"sunset":1687151821,"temp":299.88,"feels_like":300.37,"pressure":1016,"humidity":51,"dew_point":288.91,"clouds":0,"visibility":10000,"wind_speed":6.17,"wind_deg":80,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-19 04:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687147200,"sunrise":1687103447,"sunset":1687151821,"temp":299.6,"feels_like":299.6,"pressure":1015,"humidity":48,"dew_point":287.71,"clouds":20,"visibility":10000,"wind_speed":3.6,"wind_deg":50,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-19 05:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687150800,"sunrise":1687103447,"sunset":1687151821,"temp":298.41,"feels_like":298.48,"pressure":1016,"humidity":57,"dew_point":289.29,"clouds":0,"visibility":10000,"wind_speed":3.09,"wind_deg":60,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-19 06:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687154400,"sunrise":1687103447,"sunset":1687151821,"temp":298.15,"feels_like":298.3,"pressure":1016,"humidity":61,"dew_point":290.11,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":60,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-19 07:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687158000,"sunrise":1687103447,"sunset":1687151821,"temp":298.02,"feels_like":298.23,"pressure":1017,"humidity":64,"dew_point":290.75,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":60,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-19 08:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687161600,"sunrise":1687103447,"sunset":1687151821,"temp":297.57,"feels_like":297.87,"pressure":1017,"humidity":69,"dew_point":291.52,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":70,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.63}}]}
# 2023-06-19 09:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687165200,"sunrise":1687103447,"sunset":1687151821,"temp":297.44,"feels_like":297.83,"pressure":1017,"humidity":73,"dew_point":292.29,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.63}}]}
# 2023-06-19 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687168800,"sunrise":1687189857,"sunset":1687238236,"temp":297.44,"feels_like":297.83,"pressure":1017,"humidity":73,"dew_point":292.29,"clouds":0,"visibility":10000,"wind_speed":1.54,"wind_deg":60,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.63}}]}
# 2023-06-19 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687172400,"sunrise":1687189857,"sunset":1687238236,"temp":297.15,"feels_like":297.51,"pressure":1017,"humidity":73,"dew_point":292.01,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-19 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687176000,"sunrise":1687189857,"sunset":1687238236,"temp":297.15,"feels_like":297.38,"pressure":1016,"humidity":68,"dew_point":290.88,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-19 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687179600,"sunrise":1687189857,"sunset":1687238236,"temp":297.02,"feels_like":297.5,"pressure":1016,"humidity":78,"dew_point":292.95,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-19 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687183200,"sunrise":1687189857,"sunset":1687238236,"temp":296.96,"feels_like":297.3,"pressure":1015,"humidity":73,"dew_point":291.83,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.31}}]}
# 2023-06-19 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687186800,"sunrise":1687189857,"sunset":1687238236,"temp":296.96,"feels_like":297.3,"pressure":1015,"humidity":73,"dew_point":291.83,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"rain":{"3h":0.31}}]}
# 2023-06-19 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687190400,"sunrise":1687189857,"sunset":1687238236,"temp":296.96,"feels_like":297.3,"pressure":1016,"humidity":73,"dew_point":291.83,"clouds":75,"visibility":10000,"wind_speed":1.54,"wind_deg":70,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":0.31}}]}
# 2023-06-19 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687194000,"sunrise":1687189857,"sunset":1687238236,"temp":297.49,"feels_like":297.89,"pressure":1017,"humidity":73,"dew_point":292.34,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":0,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-19 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687197600,"sunrise":1687189857,"sunset":1687238236,"temp":297.81,"feels_like":298.5,"pressure":1017,"humidity":83,"dew_point":294.73,"clouds":20,"visibility":10000,"wind_speed":2.06,"wind_deg":90,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-19 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687201200,"sunrise":1687189857,"sunset":1687238236,"temp":297.95,"feels_like":298.39,"pressure":1017,"humidity":73,"dew_point":292.78,"clouds":20,"visibility":10000,"wind_speed":4.12,"wind_deg":90,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-19 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687204800,"sunrise":1687189857,"sunset":1687238236,"temp":299.28,"feels_like":299.28,"pressure":1017,"humidity":65,"dew_point":292.19,"clouds":20,"visibility":10000,"wind_speed":4.12,"wind_deg":70,"wind_gust":7.72,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"3h":0.44}}]}
# 2023-06-19 21:00:00
# ...
# 2023-06-27 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687860000,"sunrise":1687881166,"sunset":1687929519,"temp":297.21,"feels_like":297.58,"pressure":1021,"humidity":73,"dew_point":292.07,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":80,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-27 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687863600,"sunrise":1687881166,"sunset":1687929519,"temp":296.92,"feels_like":297.28,"pressure":1020,"humidity":74,"dew_point":292.01,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":3.6,"wind_deg":70,"weather":[{"id":300,"main":"Drizzle","description":"light intensity drizzle","icon":"09n"}]}]}
# 2023-06-27 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687867200,"sunrise":1687881166,"sunset":1687929519,"temp":296.96,"feels_like":297.38,"pressure":1018,"humidity":76,"dew_point":292.48,"uvi":0,"clouds":10,"visibility":10000,"wind_speed":6.58,"wind_deg":73,"wind_gust":9.57,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-27 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687870800,"sunrise":1687881166,"sunset":1687929519,"temp":296.92,"feels_like":297.15,"pressure":1019,"humidity":69,"dew_point":290.9,"uvi":0,"clouds":40,"visibility":10000,"wind_speed":2.57,"wind_deg":0,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-27 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687874400,"sunrise":1687881166,"sunset":1687929519,"temp":296.25,"feels_like":296.5,"pressure":1019,"humidity":72,"dew_point":290.93,"uvi":0,"clouds":40,"visibility":10000,"wind_speed":3.6,"wind_deg":70,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-27 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687878000,"sunrise":1687881166,"sunset":1687929519,"temp":296.25,"feels_like":296.42,"pressure":1019,"humidity":69,"dew_point":290.26,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":2.06,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-27 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687881600,"sunrise":1687881166,"sunset":1687929519,"temp":295.34,"feels_like":295.63,"pressure":1019,"humidity":77,"dew_point":291.12,"uvi":0,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":70,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-27 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687885200,"sunrise":1687881166,"sunset":1687929519,"temp":296.58,"feels_like":296.83,"pressure":1020,"humidity":71,"dew_point":291.02,"uvi":0.47,"clouds":40,"visibility":10000,"wind_speed":2.57,"wind_deg":0,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-27 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687888800,"sunrise":1687881166,"sunset":1687929519,"temp":298.45,"feels_like":298.71,"pressure":1020,"humidity":64,"dew_point":291.15,"uvi":1.78,"clouds":40,"visibility":10000,"wind_speed":4.12,"wind_deg":70,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-27 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687892400,"sunrise":1687881166,"sunset":1687929519,"temp":299.46,"feels_like":299.46,"pressure":1020,"humidity":59,"dew_point":290.81,"uvi":4.17,"clouds":75,"visibility":9656,"wind_speed":5.14,"wind_deg":70,"wind_gust":7.72,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]}
# 2023-06-27 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687896000,"sunrise":1687881166,"sunset":1687929519,"temp":298.21,"feels_like":298.44,"pressure":1021,"humidity":64,"dew_point":290.93,"uvi":7.22,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":20,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-27 21:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687899600,"sunrise":1687881166,"sunset":1687929519,"temp":301.13,"feels_like":302.25,"pressure":1021,"humidity":57,"dew_point":291.82,"uvi":10.09,"clouds":40,"visibility":10000,"wind_speed":3.6,"wind_deg":40,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-27 22:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687903200,"sunrise":1687881166,"sunset":1687929519,"temp":301.87,"feels_like":302.68,"pressure":1020,"humidity":52,"dew_point":291.05,"uvi":12.14,"clouds":40,"visibility":10000,"wind_speed":6.17,"wind_deg":50,"wind_gust":9.77,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-27 23:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687906800,"sunrise":1687881166,"sunset":1687929519,"temp":302.35,"feels_like":302.59,"pressure":1020,"humidity":46,"dew_point":289.55,"uvi":12.27,"clouds":40,"visibility":10000,"wind_speed":4.63,"wind_deg":50,"wind_gust":10.8,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-28 00:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687910400,"sunrise":1687881166,"sunset":1687929519,"temp":303.11,"feels_like":303.28,"pressure":1019,"humidity":44,"dew_point":289.54,"uvi":10.66,"clouds":20,"visibility":10000,"wind_speed":4.63,"wind_deg":70,"wind_gust":10.29,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# 2023-06-28 01:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687914000,"sunrise":1687881166,"sunset":1687929519,"temp":301.79,"feels_like":302.46,"pressure":1019,"humidity":51,"dew_point":290.66,"uvi":7.82,"clouds":40,"visibility":10000,"wind_speed":5.66,"wind_deg":110,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-28 02:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687917600,"sunrise":1687881166,"sunset":1687929519,"temp":302.37,"feels_like":302.97,"pressure":1019,"humidity":49,"dew_point":290.56,"uvi":4.66,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":40,"wind_gust":8.75,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-28 03:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687921200,"sunrise":1687881166,"sunset":1687929519,"temp":300.35,"feels_like":301.18,"pressure":1018,"humidity":56,"dew_point":290.82,"uvi":2.08,"clouds":100,"visibility":10000,"wind_speed":6.17,"wind_deg":60,"wind_gust":10.29,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-28 04:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687924800,"sunrise":1687881166,"sunset":1687929519,"temp":300.11,"feels_like":301.25,"pressure":1018,"humidity":61,"dew_point":291.95,"uvi":0.58,"clouds":75,"visibility":10000,"wind_speed":5.14,"wind_deg":50,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-28 05:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687928400,"sunrise":1687881166,"sunset":1687929519,"temp":299.15,"feels_like":299.15,"pressure":1019,"humidity":61,"dew_point":291.05,"uvi":0,"clouds":40,"visibility":10000,"wind_speed":4.63,"wind_deg":50,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-28 06:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687932000,"sunrise":1687881166,"sunset":1687929519,"temp":298.84,"feels_like":299.11,"pressure":1019,"humidity":63,"dew_point":291.27,"uvi":0,"clouds":0,"visibility":10000,"wind_speed":2.57,"wind_deg":0,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}]}]}
# 2023-06-28 07:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687935600,"sunrise":1687881166,"sunset":1687929519,"temp":298.22,"feels_like":298.56,"pressure":1020,"humidity":68,"dew_point":291.9,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":3.09,"wind_deg":50,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}]}]}
# 2023-06-28 08:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687939200,"sunrise":1687881166,"sunset":1687929519,"temp":298.09,"feels_like":298.47,"pressure":1020,"humidity":70,"dew_point":292.24,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":4.63,"wind_deg":60,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-28 09:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687942800,"sunrise":1687881166,"sunset":1687929519,"temp":297.16,"feels_like":297.63,"pressure":1020,"humidity":77,"dew_point":292.88,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":2.57,"wind_deg":70,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-28 10:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687946400,"sunrise":1687967583,"sunset":1688015926,"temp":296.85,"feels_like":297.34,"pressure":1020,"humidity":79,"dew_point":292.99,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":2.06,"wind_deg":30,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}]}]}
# 2023-06-28 11:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687950000,"sunrise":1687967583,"sunset":1688015926,"temp":296.59,"feels_like":297.1,"pressure":1019,"humidity":81,"dew_point":293.14,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-28 12:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687953600,"sunrise":1687967583,"sunset":1688015926,"temp":296.54,"feels_like":296.92,"pressure":1018,"humidity":76,"dew_point":292.07,"uvi":0,"clouds":40,"visibility":10000,"wind_speed":2.06,"wind_deg":50,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}]}]}
# 2023-06-28 13:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687957200,"sunrise":1687967583,"sunset":1688015926,"temp":295.89,"feels_like":296.28,"pressure":1018,"humidity":79,"dew_point":292.06,"uvi":0,"clouds":100,"visibility":10000,"wind_speed":1.54,"wind_deg":50,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}]}]}
# 2023-06-28 14:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687960800,"sunrise":1687967583,"sunset":1688015926,"temp":295.89,"feels_like":296.28,"pressure":1018,"humidity":79,"dew_point":292.06,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":1.54,"wind_deg":40,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-28 15:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687964400,"sunrise":1687967583,"sunset":1688015926,"temp":295.26,"feels_like":295.67,"pressure":1018,"humidity":82,"dew_point":292.04,"uvi":0,"clouds":75,"visibility":10000,"wind_speed":2.06,"wind_deg":60,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]}]}
# 2023-06-28 16:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687968000,"sunrise":1687967583,"sunset":1688015926,"temp":295.29,"feels_like":295.75,"pressure":1019,"humidity":84,"dew_point":292.46,"uvi":0,"clouds":100,"visibility":6437,"wind_speed":2.06,"wind_deg":30,"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10d"},{"id":701,"main":"Mist","description":"mist","icon":"50d"}]}]}
# 2023-06-28 17:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687971600,"sunrise":1687967583,"sunset":1688015926,"temp":296.22,"feels_like":296.78,"pressure":1019,"humidity":84,"dew_point":293.37,"uvi":0.47,"clouds":75,"visibility":10000,"wind_speed":2.57,"wind_deg":40,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-28 18:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687975200,"sunrise":1687967583,"sunset":1688015926,"temp":298.15,"feels_like":298.53,"pressure":1019,"humidity":70,"dew_point":292.3,"uvi":1.81,"clouds":75,"visibility":10000,"wind_speed":4.12,"wind_deg":60,"wind_gust":7.72,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]}
# 2023-06-28 19:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687978800,"sunrise":1687967583,"sunset":1688015926,"temp":299.47,"feels_like":299.47,"pressure":1019,"humidity":63,"dew_point":291.87,"uvi":4.17,"clouds":0,"visibility":10000,"wind_speed":4.63,"wind_deg":60,"wind_gust":7.2,"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}]}]}
# 2023-06-28 20:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687982400,"sunrise":1687967583,"sunset":1688015926,"temp":301.15,"feels_like":302.07,"pressure":1019,"humidity":55,"dew_point":291.27,"uvi":7.24,"clouds":40,"visibility":10000,"wind_speed":4.63,"wind_deg":50,"wind_gust":8.75,"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}]}]}
# 2023-06-28 21:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687986000,"sunrise":1687967583,"sunset":1688015926,"temp":300.35,"feels_like":301.41,"pressure":1019,"humidity":59,"dew_point":291.65,"uvi":10.12,"clouds":100,"visibility":10000,"wind_speed":6.17,"wind_deg":100,"wind_gust":8.75,"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}]}]}
# 2023-06-28 22:00:00
# {"lat":21.4469,"lon":-158.1887,"timezone":"Pacific/Honolulu","timezone_offset":-36000,"data":[{"dt":1687989600,"sunrise":1687967583,"sunset":1688015926,"temp":302.43,"feels_like":303.18,"pressure":1019,"humidity":50,"dew_point":290.94,"uvi":12.14,"clouds":20,"visibility":10000,"wind_speed":5.66,"wind_deg":90,"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]}
# Saving file: ./outputs/current_weather_forecasts/forecast_Waianae, HI Substation_2023-06-15_00-00_to2023-06-28_23-00_hr.csv

# %%
date_format = '%Y-%m-%d %H:%M:%S'

#df_forecast_current = pd.json_normalize(json_hist_data['current'])
df_hist_forecast_hr = pd.json_normalize(json_hist_data['data'])
#df_forecast_day = pd.json_normalize(json_data['daily'])
#df_forecast_minute = pd.json_normalize(json_data['minutely'])
#df_forecast_alert = pd.json_normalize(json_data['alerts'])

#df_forecast_hr.insert(1, 'dt_machine', 0)
df_hist_forecast_hr.rename(columns={"dt": "dt_machine"}, inplace = True)
df_hist_forecast_hr.insert(0, 'dt', 0)
df_hist_forecast_hr.insert(2, 'timezone', json_data['timezone'])
df_hist_forecast_hr.insert(3, 'timezone_offset', json_data['timezone_offset'])

df_hist_forecast_hr['dt'] = df_hist_forecast_hr.apply(lambda x: convert_timestamp_to_text(x['dt_machine'], date_format), axis =1)

results_filename = './outputs/current_weather_forecasts/forecast_{}_{}_hourly.csv'.format(sites[site_number]['name'], '2018-06-18')
print('Saving file: {} '.format(results_filename))
df_hist_forecast_hr.to_csv(results_filename, index = False)
# Out:
# Saving file: ./outputs/current_weather_forecasts/forecast_Donalsonville, GA Substation_2018-06-18_hourly.csv

# %%
df_forecast_day = pd.json_normalize(json_data['daily'])
df_forecast_day.rename(columns={"dt": "dt_machine"}, inplace = True)
df_forecast_day.insert(0, 'dt', 0)
df_forecast_day.insert(2, 'timezone', json_data['timezone'])
df_forecast_day.insert(3, 'timezone_offset', json_data['timezone_offset'])

results_filename = './outputs/current_weather_forecasts/forecast_{}_{}_daily.csv'.format(sites[site_number]['name'], datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
print('Saving file: {} '.format(results_filename))
df_forecast_day.to_csv(results_filename, index = False)
# Out:
# Saving file: ./outputs/current_weather_forecasts/forecast_Donalsonville, GA Substation_2023-06-26_15-22-08_daily.csv

# %%
df_forecast_current.rename(columns={"dt": "dt_machine"}, inplace = True)
df_forecast_current.insert(0, 'dt', 0)
df_forecast_current['dt'] = df_forecast_current.apply(lambda x: convert_timestamp_to_text(x['dt_machine'], date_format), axis =1)

df_forecast_current.insert(2, 'timezone', json_data['timezone'])
df_forecast_current.insert(3, 'timezone_offset', json_data['timezone_offset'])

results_filename = './outputs/current_weather_forecasts/forecast_{}_{}_current.csv'.format(sites[site_number]['name'], datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
print('Saving file: {} '.format(results_filename))
df_forecast_current.to_csv(results_filename, index = False)
# Out:
# Saving file: ./outputs/forecast_Waianae, HI Substation_2023-06-18_11-29-39_current.csv

# %%
df_forecast_minute.rename(columns={"dt": "dt_machine"}, inplace = True)
df_forecast_minute.insert(0, 'dt', 0)
df_forecast_minute['dt'] = df_forecast_minute.apply(lambda x: convert_timestamp_to_text(x['dt_machine'], date_format), axis =1)

df_forecast_minute.insert(2, 'timezone', json_data['timezone'])
df_forecast_minute.insert(3, 'timezone_offset', json_data['timezone_offset'])

results_filename = './outputs/current_weather_forecasts/forecast_{}_{}_minute.csv'.format(sites[site_number]['name'], datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
print('Saving file: {} '.format(results_filename))
df_forecast_minute.to_csv(results_filename, index = False)
# Out:
# Saving file: ./outputs/forecast_Donalsonville, GA Substation_2023-06-06_14-40-29_minute.csv
